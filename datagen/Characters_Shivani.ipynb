# %%
import os
import pandas as pd

# %%
filePath = os.path.join(os.getcwd(), 'hindi_corpus_2012_12_19', 'Hi_Newspapers.txt')
data = pd.read_csv(filePath, delimiter='\t', names=['source', 'date', 'unnamed_1', 'unnamed_2', 'text'])

# %%
filePath2 = os.path.join(os.getcwd(), 'hindi_corpus_2012_12_19', 'Hi_Blogs.txt')
data2 = pd.read_csv(filePath2, delimiter='\t', names=['source', 'date', 'unnamed_1', 'unnamed_2', 'text'])

# %%
filePath3 = os.path.join(os.getcwd(), 'hindi_corpus_2012_12_19', 'x_test.txt')
data3 = pd.read_csv(filePath3, delimiter='\t', names=['source', 'date', 'unnamed_1', 'unnamed_2', 'text'])

# %%
data.loc[:,['source', 'date', 'text']]
# Out:
#                    source        date  \
# 0            jansatta.com  2012/12/08
# 1          indiatimes.com  2012/03/21
# 2              jagran.com  2012/07/07
# 3             bhaskar.com  2012/11/02
# 4          indiatimes.com  2012/05/13
# ...                   ...         ...
# 114752         jagran.com  2012/10/31
# 114753  ranchiexpress.com  2012/11/26
# 114754    punjabkesari.in  2012/03/22
# 114755        bhaskar.com  2012/04/21
# 114756     indiatimes.com  2012/10/07
#
#                                                      text
# 0       पूर्व पाकिस्तानी कप्तान अकरम ने कहा कि यदि खिल...
# 1       - मार्केट में एक्सफोलिएटिंग लिप स्क्रब आसानी स...
# 2                                     पूर्वी कैनाल मार्ग-
# 3       संपत्ति लंबे समय में बनाई जाती है और इस काम को...
# 4       -amazon.com के किंडल ई-रीडर्स पर अब हैरी पॉटर ...
# ...                                                   ...
# 114752  मियादाद ने एक पाक चैनल से कहा कि वह नवाज को चे...
# 114753  मामला घरेलू विवाद का ः एसपी इस संबंध में कोडरम...
# 114754  स. बेअंत ङ्क्षसह के दरवाजे 24 घंटे खुले रहते थ...
# 114755                                       ॐ ब्रभवे नम:
# 114756  गौरतलब है कि शनिवार को उसने भुवनेश्वर के नंदन ...
#
# [114757 rows x 3 columns]

# %%
data2.loc[:,['source', 'date', 'text']]
# Out:
#                                  source        date  \
# 0              shrut-sugya.blogspot.com  2012/09/01
# 1           meraapnajahaan.blogspot.com  2012/11/17
# 2          rajneesh-tiwari.blogspot.com  2012/01/22
# 3            kumarshivnath.blogspot.com  2012/05/30
# 4              raviratlami.blogspot.com  2012/01/01
# ...                                 ...         ...
# 216417  tracingsilverlines.blogspot.com  2012/01/01
# 216418       bikhareakshar.blogspot.com  2012/10/01
# 216419    ekprayas-vandana.blogspot.com  2012/09/01
# 216420        kabaadkhaana.blogspot.com  2012/09/01
# 216421          sadalikhna.blogspot.com  2012/11/01
#
#                                                      text
# 0       एक नगर का सेठ अपार धन सम्पदा का स्वामी था। एक ...
# 1       घड़ी दो के टनटनाने की आवाज़ कर रही थी और संजय ...
# 2                                तस्वीर वही और बात वही है
# 3                                   'बेबसी' मुस्कुराती है
# 4                                                     112
# ...                                                   ...
# 216417                                  मन में चाह है अगर
# 216418                             लहर चले जब उसके तन की,
# 216419                        ओ तुलसी ! तुम कितनी कोमल हो
# 216420                   हाँ गाहे गाहे दीद के दौलत हाथ आए
# 216421                       जहां हर दृश्‍य मन के संशय का
#
# [216422 rows x 3 columns]

# %%
data3.loc[:,['source', 'date', 'text']]
# Out:
#                                                    source  date  text
# 0       Ne l fin de l seclo XIX l Japon era inda çconh...   NaN   NaN
# 1       Schiedam is gelegen tussen Rotterdam en Vlaard...   NaN   NaN
# 2       ГIурусаз батальонал, гьоркьор гIарадабиги лъун...   NaN   NaN
# 3       ರಾಜ್ಯಶಾಸ್ತ್ರದ ಪಿತಾಮಹೆ ಅರಿಸ್ಟಾಟಲ್. ರಾಜ್ಯಶಾಸ್ತ್ರ...   NaN   NaN
# 4       Halukum adalah kelenjar tiroid nang menonjol d...   NaN   NaN
# 5       Тухайн үед дан ганц 20кг-ын Орос баллон хэрэгл...   NaN   NaN
# 6       پاپاپلنگي، ايتا شاخه گل محمدي، هجري قمري، كُلش...   NaN   NaN
# 7       2007 йисан агьалияр сиягьдиз къачунин малуматр...   NaN   NaN
# 8       Оперативните програми (ОП) като форма на финан...   NaN   NaN
# 9       Tī Feigneux ê sì-ûi ū Béthancourt-en-Valois, C...   NaN   NaN
# 10      Glucose (/ˈɡluːkoʊs/ or /-koʊz/; C6H12O6, an a...   NaN   NaN
# 11      2005 йисуз хьайи референдумда кьабулнай къарар...   NaN   NaN
# 12      Mars (1,5 SA tumatan di matahari) ba'ukuran ta...   NaN   NaN
# 13      A l'è 'na variante ciû complessa da clascica "...   NaN   NaN
# 14      Segun l'Usana Kontado Ministerio, l'urbo havas...   NaN   NaN
# 15      كانت رحلة كوك - فولسوم - بيترسون الاستكشافية ع...   NaN   NaN
# 16      ಈ ಪಿಡುಗು ಕಡಿಮೆ ಸಂಖ್ಯೆಯಲ್ಲಿ ನಗರ ಮತ್ತು ಹಳ್ಳಿಗಳನ್...   NaN   NaN
# 17      Peny se yon enstriman plat, dan li gen lajè yo...   NaN   NaN
# 18      Des County liegt im middlan Sidwestn vo Missis...   NaN   NaN
# 19      ಪ್ರತಿ ಬಾರಿ ಹಸ್ತಪ್ರತಿಯನ್ನು ನಕಲು ಮಾಡಿದಾಗಲೂ ತಪ್ಪು...   NaN   NaN
# 20      Ko Pohuehue he nohanga o te takiwā o Tāmaki-ma...   NaN   NaN
# 21      कश्टां वरवीं जेरेंयास नितळ जालो आनी देवाक उकतो...   NaN   NaN
# 22      대구는 높고 규모가 큰 산줄기로 둘러싸인 분지 지형이다. 북쪽에는 팔공산(1,193...   NaN   NaN
# 23      Франсузмуын ыджыт пространствоэз босьтӧны керӧ...   NaN   NaN
# 24      ၂၀၁ဝ မတ် Forbes စာရင်းအရ သူ၏ကြွယ်ဝချမ်းသာမှုမှ...   NaN   NaN
# 25      Argentina adalah sebuah negara yang kaya denga...   NaN   NaN
# 26      立命館土曜講座は、大学の社会的開放および生涯教育への対応として実施している無料公開講座。当時...   NaN   NaN
# 27      The strategic leader fills the gap between the...   NaN   NaN
# 28      Актыўны ўдзельнік барацьбы супраць дыктатарска...   NaN   NaN
# 29      Al pavanais l é al dialàtt dla localitè ed Pèv...   NaN   NaN
# ...                                                   ...   ...   ...
# 117229  হাকালুকি হাওর বাংলাদেশের সর্ববৃহৎ হাওর। এটি এশ...   NaN   NaN
# 117230  1999年10月，當時還只有16歲的她在美國出道，以Mai-K名義推出首張英文《Baby I...   NaN   NaN
# 117231  چاپ و شدت قالخانا قدر و دین تماماً یالنیز الله...   NaN   NaN
# 117232  30 aprilie: Sonda spațială Messenger a NASA și...   NaN   NaN
# 117233  Fou un dels clubs més destacats del futbol gua...   NaN   NaN
# 117234  Os hunnos estioron un pueblo nomada turco d'as...   NaN   NaN
# 117235  Dät Saarlound wäd begränsed fon Luxembuurich i...   NaN   NaN
# 117236  Thila-īege nama is of Thilan, þæt norþernmeste...   NaN   NaN
# 117237  И инагъкӀэ курытщ. Хъур фӀыцӀэщ, джабэхэр хужь...   NaN   NaN
# 117238  For those interested in creating their own wik...   NaN   NaN
# 117239  She cummey caslys-skeeal Americaanagh caslys-e...   NaN   NaN
# 117240  वासुकीमध्ये तीन मेसिए वस्तू आहेत. वासुकी आणि न...   NaN   NaN
# 117241  Ñemoarandu oikóva ko’ãga meve he’i oĩha ko’ápe...   NaN   NaN
# 117242  نها رئتن وه د اپل، جابز د سال ۱۹۸۵ وا سرمایه ۷...   NaN   NaN
# 117243  Блайтські фігури, (Інтагліо (Мохаве)) англ. Bl...   NaN   NaN
# 117244  Municipal information: Municipal Affairs Feder...   NaN   NaN
# 117245  Tlachicuēiti 21 - Āehēcamalacotl Dean, tlatēct...   NaN   NaN
# 117246  Ambazi yı wasiyet anu/unu ca. Perê ki babay yı...   NaN   NaN
# 117247  Nèd a Fusui dal 1899 int'na famàjja Zhuang.Dôp...   NaN   NaN
# 117248  רבי בנציון דייטש איז געבוירן צו זיין פאטער רבי...   NaN   NaN
# 117249  Do sezone 2008./09. je ligu činilo 14 nogometn...   NaN   NaN
# 117250  ಪರಪೋಕುದ ಇತಿಹಾಸೊ ಕಾಲೊಡು ದಕ್ಷಿಣ ರಷ್ಯೊದ ವಿಸ್ತಾರವಾ...   NaN   NaN
# 117251  Кафедра ақпараттық жүйелер саласы бойынша мама...   NaN   NaN
# 117252  Thó-mâ-tô(Ngi̍t-ngî：トマト, ho̍k-miàng：Solanum ly...   NaN   NaN
# 117253  Estiske militære tropper skal formindskes til ...   NaN   NaN
# 117254  Wakati wa mimba,homa ya Q ni vigumu kutibu kwa...   NaN   NaN
# 117255  گیلون یک ته تاریخی منطقه‌ سفیدرود دلتای طرف ای...   NaN   NaN
# 117256  តាម​រយៈ​ការ​ចិញ្ចឹម​មនោសញ្ចេតនា​ជាតិនិយម​បែប​ន...   NaN   NaN
# 117257  روس اک وفاق اے تے 1 مارچ 2008ء توں اسدیاں 83 و...   NaN   NaN
# 117258  Chute annaée-lo, la Normaundie n'est pus recou...   NaN   NaN
#
# [117259 rows x 3 columns]

# %%
sample = data.text.loc[1]

# %%
sample.strip()
# Out:
# '- मार्केट में एक्सफोलिएटिंग लिप स्क्रब आसानी से मिल जाएंगे। नहीं, तो आप बच्चों के मुलायम ब्रिसल वाले ब्रश को गोलाई में घुमाते हुए स्क्रब करें।'

# %%
from textGenerator import TextProcess
textProcessor = TextProcess()

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 

def preprocess(sentence):
    sentence=str(sentence)
    sentence = sentence.lower()
    sentence=sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url=re.sub(r'http\S+', '',cleantext)
    # rem_num = re.sub('[0-9]+', '', rem_url)
    # tokenizer = RegexpTokenizer(r'\w+')
    # tokens = tokenizer.tokenize(rem_num)  
    # filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    # stem_words=[stemmer.stem(w) for w in filtered_words]
    # lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    # return " ".join(filtered_words)
    return rem_url

# %%
preprocess(sample)
# Out:
# '- मार्केट में एक्सफोलिएटिंग लिप स्क्रब आसानी से मिल जाएंगे। नहीं, तो आप बच्चों के मुलायम ब्रिसल वाले ब्रश को गोलाई में घुमाते हुए स्क्रब करें।'

# %%
from textGenerator import TextGenerator
textgen = TextGenerator()
sample = textgen.getRandomText()
# preprocess(sample)
sample
# Out:
# 'येदयुरप्पा, उनके बेटे और सांसद बी वाई राघवेन्द्र, बी वाई विजयेन्द्र, दामाद आर एन सोहन कुमार कोर्ट में मौजूद थे। कोर्ट ने 16 नवंबर को इन्हें मौजूद होने के लिए समन जारी किया था। अदालत ने यह भी कहा कि मामले में जांच खत्म हो चुकी है।'

# %%
temp = sample

# %%
sample = temp
preprocess(sample)
# print(f"Sample : {sample}")
sample = sample.strip()
# print(f"Sample : {sample}")
sample = sample.splitlines()
print(f"Sample : {sample}")
sample = sample[0]
sample = sample.split()
print(f"Sample : {sample}")
# word = sample[-5]
# print(f"Word : {word}")
# Out:
# Sample : ['परिवार के सदस्यों के बीच यदि मतभेद हो तो आए दिन विवाद होते रहते हैं। यह मतभेद अक्सर पति-पत्नी के बीच होते हैं। कई बार इनके कारण बड़ा विवाद भी हो जाता है। इसका असर परिवार के अन्य सदस्यों पर भी पड़ता है। कई बार आप यह समझ ही नहीं पाते कि इस समस्या से कैसे छुटकारा पाएं ?']
# Sample : ['परिवार', 'के', 'सदस्यों', 'के', 'बीच', 'यदि', 'मतभेद', 'हो', 'तो', 'आए', 'दिन', 'विवाद', 'होते', 'रहते', 'हैं।', 'यह', 'मतभेद', 'अक्सर', 'पति-पत्नी', 'के', 'बीच', 'होते', 'हैं।', 'कई', 'बार', 'इनके', 'कारण', 'बड़ा', 'विवाद', 'भी', 'हो', 'जाता', 'है।', 'इसका', 'असर', 'परिवार', 'के', 'अन्य', 'सदस्यों', 'पर', 'भी', 'पड़ता', 'है।', 'कई', 'बार', 'आप', 'यह', 'समझ', 'ही', 'नहीं', 'पाते', 'कि', 'इस', 'समस्या', 'से', 'कैसे', 'छुटकारा', 'पाएं', '?']

# %%
def isEndOfLine(x):
    if u'\u0964' <= x <= u'\u0965' :
        return True
    return False
    

def isMatra(x):
    if (u'\u0901' <= x <= u'\u0903' or 
        u'\u093C' <= x <= u'\u094F' or
        u'\u0951' <= x <= u'\u0954' or
        u'\u0951' <= x <= u'\u0954' or
        u'\u0962' <= x <= u'\u0963'):
        return True
    return False
def isVowel(x):
    if (u'\u0905' <= x <= u'\u0914' or 
        u'\u0960' <= x <= u'\u0961'):
        return True
    return False
def isConsonant(x):
    if (u'\u0915' <= x <= u'\u0939' or 
        u'\u0958' <= x <= u'\u095F'):
        return True
    return False

def isOM(x):
    if x == u'\u0950' :
        return True
    return False

# %%
pd1 =data.text
pd2 =data2.text
new_sample = pd.concat([pd1, pd2], ignore_index=True)

new_sample.head()
# Out:
# 0    पूर्व पाकिस्तानी कप्तान अकरम ने कहा कि यदि खिल...
# 1    - मार्केट में एक्सफोलिएटिंग लिप स्क्रब आसानी स...
# 2                                  पूर्वी कैनाल मार्ग-
# 3    संपत्ति लंबे समय में बनाई जाती है और इस काम को...
# 4    -amazon.com के किंडल ई-रीडर्स पर अब हैरी पॉटर ...
# Name: text, dtype: object

# %%
vowel=0
consonant=0
matra=0
eofLine=0
OM=0
vowel_matra=0
half_vowel=0
consonant_matra=0
constant_half_matra=0;
word_start_matra=0
half_consonant_vowel=0
half_consonant_matra=0
dictionary_vowel = {}
dictionary_consonant = {} 
words_with_half_consonant_following_vowel={}
words_with_half_consonant_following_matra={}
words_with_vowels_following_matra={}
constant_and_vowel_combination={}
words_starting_with_matra = []
words_having_half_vowel=[]

wordCount = 0
for para in new_sample:
    words = para.split()
    for word in words:
        characters = list(word)
        wordCount += 1
#         if(isMatra(characters[0])):
#             word_start_matra+=1
        for index, char in enumerate(characters):
            if(isMatra(char)):
                matra = matra+1
                if(index==0):
                    word_start_matra += 1
                    words_starting_with_matra.append(word)
                
            elif(isVowel(char)):
                if(index+1 < len(characters)):
                    if(isMatra(characters[index+1])):
                        vowel_matra=vowel_matra+1
                        if word in words_with_vowels_following_matra: 
                            words_with_vowels_following_matra[word] += 1
                        else: 
                            words_with_vowels_following_matra.update({word: 1}) 
                        
                    if(characters[index+1] == u'\u094D'):
                        half_vowel+=1
                        words_having_half_vowel.append(word)
                if char in dictionary_vowel: 
                    dictionary_vowel[char] += 1
                else: 
                    dictionary_vowel.update({char: 1}) 
                vowel=vowel+1
            elif(isConsonant(char)):
                if(index+1 < len(characters)):
                    if(isMatra(characters[index+1])):
                        consonant_matra=consonant_matra+1
                    if(index+2 < len(characters)):   
                        if(characters[index+1] == u'\u094D'):
                            if(isVowel(characters[index+2])):
                                half_consonant_vowel+=1
                                if word in words_with_half_consonant_following_vowel: 
                                    words_with_half_consonant_following_vowel[word] += 1
                                else: 
                                    words_with_half_consonant_following_vowel.update({word: 1}) 
                            if(isMatra(characters[index+2])):
                                half_consonant_matra+=1
                                if word in words_with_half_consonant_following_matra: 
                                    words_with_half_consonant_following_matra[word] += 1
                                else: 
                                    words_with_half_consonant_following_matra.update({word: 1})
                if char in dictionary_consonant: 
                    dictionary_consonant[char] += 1
                else: 
                    dictionary_consonant.update({char: 1}) 
                
                consonant = consonant+1
            elif(isEndOfLine(char)):
                eofLine = eofLine+1
            elif(isOM(char)):
                OM = OM+1

# %%
print(f"Matra : {matra}")
print(f"Vowel : {vowel}")
print(f"Consonant : {consonant}")
print(f"end of line : {eofLine}")
print(f"OM : {OM}")
print(f"Word starting with a Matra : {word_start_matra}")
print(f"Vowels followed by a matra : {vowel_matra}")
print(f"Consonant followed by a matra : {consonant_matra}")
print(f"half vowel : {half_vowel}")
print(f"Number of words : {wordCount}")
print(f"half cononants followed by a matra : {half_consonant_matra}")
print(f"half cononants followed by a Vowel: {half_consonant_vowel}")
print(f"Words having half vowel: {words_having_half_vowel}")
print(f"Words starting with a matra : {words_starting_with_matra}")
print(f"Words with vowels followed by a matra : {words_with_vowels_following_matra}")
# Out:
# Matra : 20007689
# Vowel : 2295243
# Consonant : 29407930
# end of line : 507007
# OM : 275
# Word starting with a Matra : 756
# Vowels followed by a matra : 140669
# Consonant followed by a matra : 18186346
# half vowel : 18
# Number of words : 13532910
# half cononants followed by a matra : 856
# half cononants followed by a Vowel: 474
# Words having half vowel: ['जकिउ्द्दीन', 'कोइ्रü', 'गइ्र', 'कोइ्र्र', 'हुइ्र्र', 'जाए्गा।', 'हुइ्र्र', 'सुरमइ्रर्', 'जुलार्इ्र', 'कोइ्र', 'उ्देश्य', 'राष्अ्रपति', 'आइ्र', 'स्काउ्ट्स', 'चढार्इ्', '‘‘देखो-श्-अ्!’’', 'कोई्र', 'हेडलाइ्ट्स']
# Words starting with a matra : ['ा', 'ा', 'ॅषिकेश', 'ः', 'ंठहराव', 'ूबाजार', 'ंऔर', 'ेबाद', 'ः', '्', 'ारण', 'ंकिया', 'ाएंगे', 'ः', 'ः', 'ंलचर', 'ः', 'ा', 'ै', '़िखलाड़ी', 'ः', 'ः', 'ेवाले', 'ः', 'ाा,', 'ाराखंड', 'ा', 'ंिवश्वविख्यात', 'ः', 'ंने', 'ंको', 'ंदे', 'ः', 'ा', 'ा', 'ा’', 'ा', 'ा', 'ाीय', 'ेसे', 'ा', 'ा', 'ार', 'ाकम', 'ंने', 'ा', 'ः', 'ः', 'ः', 'ः', 'ा', 'ंसुस्ती', '़49', 'ः', 'ः', 'ो', 'े', 'े', 'ै', 'ंचार', 'ों', 'ः', 'ीका,', '्रदमुक', 'ा', 'ा', 'ः', 'ॉॉ', 'ेसी', 'ौर', 'ांसी', '़कर', 'ः', 'ः', 'ा', 'ः(4', 'िउच्च', 'ाीगंगानगर', 'ाीय,', 'ः', 'ोंच', 'ंकांग्रेस', 'ारोबार', 'ेबीएसई', 'ः', 'ः', 'ेमें', 'ेयह', 'ा', 'ा', 'ा', 'ः', 'ंआरोपियों', 'ेवेबसाइट', '़कर', 'ः', 'ंने', 'ः', 'ः', 'ः', 'ः', 'ः', 'ः', 'ः', 'ः', 'ि1कसे', 'ः', 'ंमंजूरिया', 'ः', 'ः', 'ः', 'ा', '्र', '्र', 'ः', 'ः', 'ै', 'ै', 'ः', 'ः', 'ंने', 'ः', 'ं।', '्रेलवे', 'ै', 'ंबड़ौदा', '्', 'ंगंगवार', 'ंने', 'ः', 'ंिवभागों', 'ार', 'ंपिछले', 'ः', 'ः', 'ंही', 'े', 'ः', 'ा', 'ः', 'ः', 'ः', 'ः', 'ंअंतिम', 'ः', 'ः', 'ः', 'ार्रवाई', 'ः', 'ः', 'ीन', 'ः', 'ा', 'ी', 'ायर', 'ेकी', 'े', 'े', 'ं।', 'ंपर', 'ः', 'ांट', 'ांट', 'ांट', '्र', 'ंकि', 'ः', 'ंसोने', 'ः', 'ंयह', 'ुपसंद', 'ः', 'ः', 'ः', 'ेस', '्रदमुक', 'ी', 'ी', 'ोप-', 'ृ1,452', 'ार्य', '्रदमुक', 'ः', 'ंने', 'ेकला,', 'ंऔर', 'ी', 'ः', 'ः', 'ंने', 'ोमवर्क', 'ः', 'ांग', '्रआकलनों', 'ेकेविन', 'ः', 'ं', 'ः', 'ः(20', 'ंिचंताजनक', 'ः', 'ः', 'ंिवश्व', 'ः', 'ेबताया', 'ारी', 'ा', 'ांतिकारी', 'ंवह', 'ंसिह,', '्', '्दक्षिण', '्', '्', '्', '्', '्एफएमसीजी', '्', '्', '्', 'ः', 'ोई', 'ा', 'ः', 'ारखाने', 'ं15', 'ा', 'ा', 'ेक्वांटो', 'ंएमसीए', 'ंने', 'ः', 'ंिवधेयक', 'ः', 'ः', 'ः', '्रछट', 'ः', 'ंिजनके', '्िमलीं', 'ंिचंता', 'ंशामिल', 'ंसे', 'ः', 'ार्मासिस्टों', 'ाम', 'ंसे', 'ंवरीयता', 'ंझुकने', 'ंकारोबार', 'ं', 'ः', 'े', 'ः', 'ी', 'िायों', 'ा', 'ोर्ट', 'ो', 'ो', 'ंसे', 'ोम', 'ाृंखला', 'ंसावधानियां', 'ोध', 'ी।', 'ः', 'ः', 'ंइन्हीं', 'ः', 'ः', 'ार', 'ो', 'ः', 'ुकमार', 'ा', 'ः', '्', 'ी', 'ः', 'ः', 'ा', 'ेबेहतर', 'ंसीडी', 'ंबद', 'ो', 'ंिसंह', 'ंयह', 'ंगिरावट', 'ंवोट', 'ंटी-20', 'ंयही', 'ंकारोबार', 'ः', 'ोंड्स', 'ो', 'ा', '्रहाल', 'ा', '्िदन)', 'ौर', 'ः', 'े', 'ः', 'ः', 'ंके', 'ंवर्षो', 'ा', 'ो', '्', 'ायत', 'ः', 'ः', 'ौलपुर,जैसलमेर,बारां,प्रतापगढ़', 'ंसे', 'ंिंवधेयक', 'ंवीआईपी', 'ः', 'ंआत्म', 'ों', 'ा', 'ंिचदंबरम', 'ंपर', 'ः', 'ी', 'ः', 'ोड़', 'ः', 'ोध', 'ुईंया', 'ोक्ता', '्र-कारपेट', 'ेप्रभावी', 'िमली', 'ः', 'ोंकलिन', 'ोंकलिन', 'ै', 'ै', 'ेने', 'ावा', 'ंिवधेयक', '़', 'ाना', 'ंट्वीट', 'ंिसंह,', 'ंिवभाग', 'ंशुक्रवार', 'ैजैसे', 'ाियान्वनयन', 'ाियान्वयन', 'ंची', 'ः', 'ेकहा', 'ंइस', 'ाल', 'ंनिवेशकों', 'ंिमलेगा।', 'ा', 'ः', 'ः', 'ी', 'ः', 'ी', '्', '्', '्', '्', '्', '्', 'ंिसन्हा', 'ः', 'ः', 'ः', '्र', 'ंहुआ', 'ाीय', '्', '्', '्', 'िपट्रर', 'ेलेना-देना', 'ः', 'ः', 'ारी', 'े', 'ः', 'ा', 'ंसिंह,', 'ंसिर्फ', 'ांति', 'ेकी', 'ः', '्र', 'ः', 'ः', 'ः', 'ः', 'ः', 'ः', 'ः', 'ंहैं.', 'ः', 'िध', 'ॅ', 'ाकी', 'ंजरूरत', '्समय', 'ै।', 'ंच', 'ाचार', 'िखलाफ', 'ामक', 'ा', 'ंयही', 'ु', 'ेमूँगफनी', 'िकवह', 'ी', 'े', 'ा', 'ंहै', 'ंप', 'ेइस', 'ंतो', 'ंसंगमरमर', 'िशक्षण', 'िशक्षक', 'ः', 'िभगाती', 'ंतो', 'ाय-पान', 'ः', 'ंसेवा', 'ं', 'ः', 'िक', 'ाकरना', 'ाा,', 'ी', 'ंहोगा', 'ेकर', 'ी', '॔मित्रातापूर्ण', 'े', 'ंकी', 'ााटी', 'ाुमावदार', 'ंतो', '्भी', 'ऽ', 'ंतो', 'ंतब', 'ाले', 'ंबताइये', 'ंिसंह', 'ानावाला', 'ेछुपाने', 'ंमें', 'ेविषय', 'िफर', '़लाई', '़लाई', '़', '़', '़', '़के', 'ः', 'ो', 'ेके', 'ा', 'ेचलिए,', 'ं', 'ों', 'ारदाता', 'ं।', '़ढ़की', 'ंमें', 'ः', 'ः', 'िक', 'ः', 'ंहै', 'ः', 'ः', '्कान', '्बीमारी', 'ऽ', 'ंके', 'ा', 'ः', 'ंहैं', '्तथा', 'ंजरूरत', 'ा', 'ंपरा', 'िदया।जब', 'ं', 'ंहैं।', 'ी', 'ं', 'ंतो', 'ंिचंता', 'ऽ', '्सुबह', 'ें', 'ंिसह', 'ःई', 'ूूू।ंिेजदमूेपदकपं।दमज', '्में', 'ऽ', 'ंिचंतन', 'ंतो', '़बीच', '़', '़', '़', '्रपद्रेश।', 'ाी', 'े', 'िं', 'ंने', 'िाकई', 'ंको', 'ुचकी', '्सरकार', '़', '़', '़', 'ै?', 'ंगमंजदा', 'िफक्रो', 'ी', 'ी', 'ंसार', 'ः', 'िफल्म', 'ा', 'िक', 'ऽ', 'ंतो', 'ंपर', 'ेकदम', 'ााषा', 'ंको', 'ऽ', 'े', 'ेट', 'ः', 'ः', 'ं', 'ौलए', 'ा', 'ंलिखा', 'ं', 'ाखुशियॉँ', 'ऽ', '॔निशंक’', '॔हिन्दी', '॔ताकी', '॔सफलता', '॔वटवृक्ष’', 'ार्यक्रमों', '़िखला़फ' ...
# Words with vowels followed by a matra : {'जाएंगे।': 1214, 'महिलाएं': 892, 'सर...अंदर': 1, 'एंटीऑक्सिडेंट': 3, 'डिस्काउंट': 86, 'उपभोक्ताओं': 463, 'कार्यकर्ताओं': 879, 'अंत': 1553, 'ऊंची': 473, 'अंग्रेज': 195, 'अंग्रेजों': 433, 'एंड': 1136, 'आंकड़ों': 238, 'जाएंगे,': 147, 'मुद्राएंलगेंगी.': 1, 'अंतरराष्ट्रीय': 1463, 'इंटरपोल': 30, 'पहलुओं': 246, 'लगाएंगे।': 26, 'आंकड़ों': 316, 'नेताओं': 2668, 'आंदोलन': 3086, 'इंकार': 611, 'इंग्लैंड': 1177, 'एंबोन': 1, 'अंतरिक्ष': 528, 'अंदाज': 650, '‘इंगलिश': 5, 'अंगरेजी': 229, 'अंश.': 10, 'संस्थाओं': 550, 'समस्याएं': 406, 'संवाददाताओं': 469, 'ऊंची)': 1, 'इंजिनियर्स': 5, 'महिलाओं': 2627, 'आंखों': 1152, 'युवाओं': 855, 'आंतकी': 8, 'इंटरनेट': 848, 'घबराएं': 13, 'चयनकर्ताओं': 159, 'आंखें': 591, 'आं': 2, 'इंद्र': 123, 'दवाओं': 316, 'गईं': 362, 'अंबानी': 209, 'ऊंचाइयों': 31, 'फाउंडेशन': 208, 'फाउंडेशन,': 4, 'इंस्टीच्यूट': 20, 'अंतर्गत': 627, 'इंतजार': 1283, 'अंगदान': 67, 'शोधकर्ताओं': 197, 'अंधेरे': 390, 'अंग्रेजी': 1315, 'समस्याओं': 1007, 'साइंस(भू-': 1, 'चिंताएं': 81, 'लाएं।': 17, 'इंदर': 49, 'आंकड़ा': 269, 'एंड्रॉयड': 115, 'इंस्टीटयूट': 10, 'संभावनाएं': 227, 'इंडिया,': 95, 'इंजीनियरों': 69, 'एयरलाइंस': 267, 'अंसारी': 312, 'ऊंचा।': 2, 'दिखाएंगे।': 12, 'अंगूठी': 59, 'जाएं,': 160, "'एंग्री": 2, 'सीमाएं': 103, 'हुआंगनिहे': 1, 'वस्तुओं': 419, 'आंकड़े': 286, 'अंजान': 60, 'आएंगे।': 232, 'अंतिम': 2490, 'अवधारणाओं': 33, 'आंतरिक': 336, 'इंजीनियरिंग': 358, 'शाखाओं': 108, 'अंजाम': 767, 'अंबर': 23, 'साजिशकर्ताओं': 14, 'इंडिया': 2440, 'छात्र-छात्राओं,': 2, 'एंड्रॉएड': 2, 'आॢथक': 40, 'बाध्यताएं': 2, 'कुओं': 28, 'गोइंग': 10, 'इंडस्ट्री': 595, 'इंटरटेनमेंट': 7, 'अकाउंट': 297, 'घटनाओं': 792, 'इंफ्रास्ट्रक्चर': 82, 'साइंटिस्ट्स': 9, 'एेंड': 5, 'इंडस्ट्रीज': 158, 'सूचनाओं': 139, 'अंडर': 115, 'इंडियन': 760, 'डिजाइंस': 42, "'अंग्रेजी": 3, 'इंच': 273, 'कन्याओं': 74, 'घटनाएं': 433, 'चिंताओं': 123, 'पुरुष-महिलाएं': 2, 'उंगलियां': 61, 'जाऊं': 191, 'आऊं।': 12, 'आऊंगा।': 20, 'अंदरखाने': 19, 'इंस्पेक्टर': 248, "जाएं।'": 4, 'आंतिम': 2, 'काउंटी': 58, 'अंगवस्त्र': 5, 'इंतानोन': 2, 'अंक': 2800, 'विदेश-यात्राएं': 1, 'सीमाओं': 211, 'इंजेक्शनों': 1, 'अंतर': 980, 'इंट्रो': 5, 'ऊंचाई': 353, 'सुविधाएं': 428, 'हुईं': 200, 'अंदाजा': 376, 'इंदौरा': 37, 'करवाएंगे।': 21, 'आंकड़ा': 98, 'जाएं': 430, 'जाएं।': 496, 'लिएंडर': 117, 'डब्ल्यूआएिसपीए': 1, 'इंडोनिशिया': 3, 'अंतर्राष्ट्रीय': 350, 'अंतत:': 270, "दिखाएंगे।''": 1, 'चढ़ाएं।': 42, 'छटाएं': 2, 'एंड्रयू': 41, 'इंडोर': 33, 'उठाएंगे।': 44, 'बाएं': 159, 'दाएं': 93, 'उठाएं।': 28, 'ऐंटिडिप्रेसेंट': 1, 'दवाएं': 186, 'काउंसलिंग': 54, 'कक्षाओं': 84, 'कविताओं': 526, 'लगाएं।': 171, 'मिलाएं।': 21, 'बेइंतहा': 22, 'इंदिरा': 651, 'ईंधन': 178, 'आंसूगैस,': 1, 'काउंटर,': 2, 'थलसेनाओं': 3, 'राउंड': 225, 'परंपराओं': 136, 'यात्राओं': 117, 'इंजॉय': 36, 'पाएंगी।': 27, 'जाएंगी।': 284, 'एंटो': 1, 'एंटनी': 146, 'इंटरनेशनल': 258, 'इंग्लिश': 186, 'अंश': 382, 'सेवाओं': 367, 'स्पर्धाओं': 19, 'गईं।': 414, 'क्लाइंट': 31, 'अंदर': 2409, 'गोपिकाएं': 3, "इंडिया'": 24, 'आएंगी.': 20, 'विक्रेताओं': 42, 'योजनाओं': 831, 'अंदरूनी': 152, 'अंगों': 180, 'डिस्काउंट्स': 3, 'अपेक्षाओं': 64, 'विद्याओं': 11, 'सुख-सुविधाएं': 11, 'जाऊंगा.’': 1, 'बाधाएं': 58, 'इंसुलिन': 40, 'सूरमाओं': 6, 'ग्राउंड': 121, 'खिलाएं।': 17, 'शाखाएं': 50, 'ब्लाइंड': 12, 'एंटनी,': 16, 'एंटरटेनमेंट': 50, 'पाएंगे,': 36, 'धातुओं': 100, 'कोशिकाओं': 105, 'एंटी': 129, '‘ओंकारा’': 1, 'आऊंगी.': 3, 'वेस्टइंडीज': 286, 'आंख': 496, 'इंटरेस्ट': 75, 'एलएंडटी1.02': 1, 'आंसू': 515, 'क्वालीफाईंग': 8, 'इंटरव्यूज': 3, 'बढ़ाएंगे।': 12, 'परियोजनाओं': 352, 'आंकड़े': 166, 'एंट्री': 226, 'अकाउंटधारक': 2, 'इंद्रजीत': 24, 'इंटर': 163, 'धनपशुओं': 3, 'संस्थाओं,': 17, 'मर्यादाओं,': 2, '17763.59अंक': 1, 'ऊंचे': 329, 'एंव': 66, 'अंपायर': 78, 'अंपायरों': 37, 'नजरअंदाज': 213, 'आंत': 27, 'बोइंग': 43, 'योजनाएं': 275, 'इंटीग्रेटेड': 19, 'अंडमान': 38, 'आंदोलनों': 237, 'एंडोर्स': 8, "'इंडिया": 28, 'उंगलिया': 7, 'ऐंटि-लॉक': 1, 'काउंसिल': 248, 'चुकाएं।': 1, 'इंसाफ,': 2, 'एंडी': 79, 'आएंगी': 33, 'लगाएंगी।': 6, 'चर्चाओं': 91, 'एंट्रेंस': 15, 'इंश्योरेंस': 345, 'अमाउंट': 21, 'परियोजनाएं': 84, 'इंजन': 362, 'सफलता ...

# %%
for allKeys in dictionary_vowel: 
    print(f"Frequency of {allKeys} : {dictionary_vowel[allKeys]}")
# Out:
# Frequency of अ : 429904
# Frequency of औ : 205808
# Frequency of ऐ : 34538
# Frequency of उ : 304315
# Frequency of ए : 410350
# Frequency of इ : 294766
# Frequency of आ : 337944
# Frequency of ई : 187285
# Frequency of ऊ : 14706
# Frequency of ओ : 62414
# Frequency of ऑ : 10063
# Frequency of ऋ : 2121
# Frequency of ऎ : 822
# Frequency of ॠ : 38
# Frequency of ऍ : 157
# Frequency of ऌ : 3
# Frequency of ऒ : 9

# %%
for allKeys in dictionary_consonant: 
    print(f"Frequency of {allKeys} : {dictionary_consonant[allKeys]}")
# Out:
# Frequency of प : 1254359
# Frequency of र : 3336110
# Frequency of व : 973866
# Frequency of क : 3623226
# Frequency of स : 2110400
# Frequency of त : 1768862
# Frequency of न : 2238889
# Frequency of म : 1736874
# Frequency of ह : 2146189
# Frequency of य : 1207779
# Frequency of द : 1006684
# Frequency of ख : 312081
# Frequency of ल : 1425704
# Frequency of ड़ : 43471
# Frequency of ब : 899384
# Frequency of भ : 419506
# Frequency of च : 454628
# Frequency of श : 448619
# Frequency of ट : 436552
# Frequency of ड : 310843
# Frequency of ग : 787541
# Frequency of ज : 925475
# Frequency of थ : 332103
# Frequency of छ : 127886
# Frequency of फ : 215071
# Frequency of घ : 70504
# Frequency of झ : 58741
# Frequency of ध : 245538
# Frequency of ढ : 48425
# Frequency of ण : 129405
# Frequency of ठ : 78913
# Frequency of ष : 196826
# Frequency of ढ़ : 6863
# Frequency of ऩ : 1073
# Frequency of ञ : 13551
# Frequency of ङ : 1195
# Frequency of य़ : 503
# Frequency of ळ : 121
# Frequency of क़ : 1502
# Frequency of ग़ : 560
# Frequency of ख़ : 877
# Frequency of ज़ : 6391
# Frequency of ऱ : 236
# Frequency of फ़ : 4604

# %%
for allKeys in words_with_half_consonant_following_vowel: 
    print(f"{allKeys} : {words_with_half_consonant_following_vowel[allKeys]}")
# Out:
# मेंच्अच्छा : 1
# डिस्ऑर्डर : 23
# हुर्ई। : 2
# च्ए : 5
# गर्इं। : 21
# हुर्इं : 4
# र्इंट, : 1
# ‘र्इंटें’, : 1
# कार्रवार्ई : 1
# प्रतिच्अच्छी : 1
# हुर्इं, : 4
# बनार्इं, : 1
# सेमीफ्इानल : 1
# कुर्आन : 2
# लम्बार्ई : 1
# आर्इं : 3
# रूप्ए : 2
# किसीच्उच्च : 1
# इतनाच्अच्छे : 1
# गर्ई। : 5
# वाक्ओवर : 1
# उठार्इं। : 1
# सार्इंनाथ : 1
# गर्इं : 8
# ज्एगा। : 1
# रुप्ए : 1
# सुनार्ई : 1
# र्इंटे : 2
# ‘र्इंटें-2’ : 1
# र्इंटों : 1
# र्इंटें/ : 1
# गर्इं? : 1
# गर्इं, : 7
# उकतार्इं : 1
# पुनर्अदायगी : 2
# लुक्ओर, : 1
# एप्एमसीजी : 3
# गर्ई, : 1
# प्रत्एक : 1
# हुर्इं। : 5
# तर्इं : 3
# केच्अच्छे : 1
# एफ्एमसीजी.बैकिंग : 1
# केच्इच्छुक : 1
# आर्इं। : 1
# र्इंधन : 4
# गुक्आिंग : 1
# एक्सचेंज.एनएसर्ई.का : 1
# रियलटी.एप्एमसीजी : 1
# बार्इं : 1
# दार्इं : 1
# मनोनितच्उच्चायुक्त : 1
# सदस्ईय : 1
# च्एक : 2
# च्अच्छा : 1
# र्अघ्य : 1
# मैक्इनतोश : 1
# बतार्इं : 1
# ’कुर्आन‘ : 2
# एफ्एमसीजी,पीएसयू : 1
# पुनर्उद्धार : 1
# र्ईधन : 3
# च्अगर : 1
# सार्इं : 1
# र्आपूत्ति : 1
# स्लीप-डिस्ऑर्डर : 1
# दाउच्च्उ : 1
# पुनर्उत्पाद : 1
# केच्उच्च : 2
# एसबीर्आ : 1
# मेंच्अच्छी-खासी : 1
# र्इंट : 2
# श्ऋर : 1
# पुनर्उत्थान : 1
# सुलझार्इं : 1
# सद्आचरण, : 1
# पार्इं! : 1
# हार्ई : 1
# डिस्अप्रूवल : 1
# नैर्ऋत्य : 2
# च्अब : 1
# एय्ऋर : 1
# क्रोन्ए, : 1
# इतनीच्अच्छी : 1
# नेच्अच्छी : 1
# चेन्न्ई : 1
# हुर्इ : 20
# गर्इ। : 22
# गर्इ : 26
# जार्इये। : 1
# स्एच्। : 1
# दानम्अध्य्न : 1
# गर्इ, : 2
# ढ़ार्इ : 2
# कोर्इ : 42
# भार्इ : 3
# रिप्लार्इ : 1
# अदरवार्इज : 1
# आर्इ : 7
# सार्इबर : 1
# हुर्इ। : 8
# प्रोफार्इल : 2
# समार्इ। : 1
# कर्इ : 13
# मोटर-सार्इकिल : 1
# शम्अ : 2
# सफार्ई : 1
# वाक़र्इ : 1
# च्च्इन्द्रजीतज्ज् : 1
# सुर्इ-धागा : 1
# आर्इ। : 6
# कोर्ई : 1
# दिखलार्इ : 3
# ब्आत : 1
# कचरा-सफार्इ : 1
# ‘सार्इंस : 1
# नर्इ : 3
# कीच्इच्छा : 1
# जतार्इ। : 1
# दिखार्इ : 8
# बनार्इ : 3
# हार्इकोर्ट : 1
# करार्इ : 1
# हीरोर्इन : 1
# पार्इप-लार्इन : 2
# पुनर्उपनिवेशीकरण : 1
# वाकर्इ : 2
# चिद्अर्पिता : 1
# बतार्इ : 1
# मर्ई : 1
# अच्छार्इ : 2
# मढर्इ : 1
# कर्ई : 1
# अमरार्इ : 2
# बधार्इ : 1
# सच्‍चार्इ : 1
# जुलार्इ्र : 1
# सच्चार्इ : 1
# टार्इट : 1
# पार्इ : 2
# कायर्ई : 1
# एम्ओयु : 1
# बीस-बार्इस : 1
# चढ़ार्इ : 1
# आ...ऊं....र्इ... : 1
# प्रार्इवेट : 1
# सुर्इ : 1
# र्इमानदार : 1
# छार्इ : 1
# र्इष्वर : 1
# व्ओ : 1
# राष्अ्रपति : 1
# र्इश्वर : 2
# कठिनार्इयों : 2
# ख्इरडा, : 1
# आरम्अभिक : 1
# सद्उपयोग : 2
# आर्अपीसी : 1
# सार्इड : 1
# सुर्इ-धागे : 1
# ‘फ़िटिंग-टार्इट’ : 1
# खिचवार्इ : 1
# आर्इं, : 1
# चिनार्इ : 2
# हुर्इपहुँच : 1
# पासर्इंट : 1
# गहरार्इ : 3
# मुस्कुरार्इ। : 1
# कुनमुनार्इ। : 1
# सार्इट : 1
# लड़खड़ार्इ : 1
# दुहार्इ : 1
# सुनार्इ : 2
# र्इंटल : 1
# निर्ऋति, : 1
# मिठार्इ : 1
# रंगार्इ : 2
# उठार्इ। : 1
# महंगार्इ : 1
# सद्इच्छा : 1
# बतार्इं। : 1
# बार्इंडिंग : 1
# हैण्ण्ण्इमरोज़ : 1
# पिटार्इ : 1
# व्ऑइस : 1
# चढार्इ् : 1
# सार्इंस : 1
# निंदार्इ, : 1
# गुडार्इ, : 1
# कटार्इ : 1
# एसएम्एस : 1
# र्इमानदारी : 1
# स्पधार्ओं : 1
# सोर्इ : 1
# लड़ार्इ : 1
# “ोखार्इन : 1
# पार्इ? : 1
# उबकार्इ : 1
# र्इच्छा : 1
# हुर्इ, : 1
# जलार्इ : 1
# मिठार्इयाँ : 1
# रेलवे-लार्इन : 1
# स्थार्इ : 1
# एफडीआर्इ : 1
# कलार्इ : 1
# सद्उपदेश, : 1
# र्इंटें : 1
# बिलसपुरहिन-’’अइसर्इ : 1
# जबरर्इ : 1
# गर्इ? : 1
# सफार्इ : 1

# %%
for allKeys in words_with_half_consonant_following_matra: 
    print(f" {allKeys} : {words_with_half_consonant_following_matra[allKeys]}")
# Out:
#  जलर्ापूत्ति : 10
#  वष्ाीüय : 11
#  सुसज्ज्ाित : 3
#  मुट््ठीभर : 2
#  केन््रद : 9
#  पुरूष्ाों : 5
#  पाष्ाüद : 4
#  मुद््दों : 9
#  क्िलंटन : 1
#  कट््टे : 1
#  क््योंकि : 1
#  विशेष्ा : 10
#  श्ुारूआती : 1
#  कट््टरता : 3
#  शतर्ें : 2
#  पुराविद्ों : 1
#  गद््दी : 1
#  थ्ौली : 3
#  घोçष्ात : 2
#  हष्ाü, : 2
#  राष्ट््रीय : 1
#  थ्ीा। : 2
#  उच्च्ंचा : 1
#  श्ृंखला : 1
#  घोष्ाणा : 7
#  श्ेवता : 1
#  बच्चच्ें : 2
#  गुड््डा : 1
#  चड््ढी : 1
#  मद््देनजर : 4
#  गिट््टी, : 1
#  ‘चट््टानें’, : 1
#  ‘मिट््टी’ : 1
#  मुद््दा : 10
#  षड्ंगी : 1
#  स्टेफ्ी : 1
#  नम्ब्ार : 1
#  अट््टालिकाओं : 2
#  विशेष्ाज्ञों : 4
#  राष्ट््रपति : 1
#  शीष्ाüक : 2
#  पट््टडकल : 1
#  छद््म : 2
#  स््ट्रीमिंग : 1
#  परिष्ाद, : 2
#  आकçष्ाüत : 2
#  वष्ाü : 20
#  पीयूष्ा : 1
#  शेष्ा : 8
#  मुद््दे : 8
#  ब्ा्रह्मपोल : 1
#  कृçष्ा : 11
#  स्ान : 6
#  उद््देश्यों : 2
#  उद््देश्य : 7
#  उद््देश्य-प्राप्ति : 1
#  श्ृंगार : 2
#  शिक्षाविद्ों, : 1
#  नेता-कार्यकत्तर्ाा : 1
#  क्िवटल : 3
#  पाठ््यपुस्तकों : 1
#  नेटवकिर्ंग : 2
#  स्ट्ेटस : 1
#  इंस्ट्र्ूमेंट्स : 1
#  विष्ाय : 7
#  स्ेह : 2
#  कार्यकत्तर्ााओं : 10
#  फीçल्ंडग : 1
#  मच्े : 1
#  बढ़ाउच्च्ंगा : 1
#  कार्यश्ौली : 1
#  सुभाष्ा : 5
#  इफ्ेटक्ट : 1
#  नवसुसज्ज्ाित : 1
#  दोष्ा : 1
#  औष्ाघि : 7
#  थ्ौले : 2
#  रफ़्तार : 2
#  राजगद््दी : 2
#  मनीष्ा : 4
#  दोष्ाी : 7
#  वाçष्ाüक : 2
#  पुरूष्ा : 5
#  बलव्ािंदर : 1
#  ज्योतिçष्ायों : 1
#  इंटरेस्ंिटग : 2
#  संतोष्ा : 1
#  धज्ज्ाियां : 5
#  रिपोटर््स : 1
#  जाउच्च्ंगा। : 2
#  पाउच्च्ंगा। : 2
#  अड््डे : 2
#  अवाडर््स : 1
#  बिल्ंिडग : 4
#  श्ाकराचार्य : 1
#  श्रृख्ांला : 1
#  कनेक््शन : 1
#  विष्ायक : 3
#  विशेष्ाज्ञ : 2
#  अभिभाष्ाक : 1
#  परिष्ाद : 14
#  अच्छच्े : 1
#  पाष्ाüदों : 3
#  पट््टी : 5
#  स्ातक : 4
#  कोष्ााध्यक्ष : 1
#  अड््डों : 2
#  कर्ार्यत्ताओं : 1
#  उच्च्ंचाई : 3
#  केन््रदीय : 4
#  ज़्यादा : 4
#  (अजेर्ंटीना), : 1
#  खानर्ापूत्ति : 1
#  महाप्रबध्ांक : 1
#  होउच्च्ं : 1
#  विष्ायाध्यापकों : 1
#  कार्यकत्तर्ाा : 7
#  उम्मीद़्वारों : 1
#  महाविद्यालय/स्ातकोत्तर : 1
#  रेड््डी, : 1
#  इकट््ठे : 2
#  स्ात्कोत्तर : 1
#  हड््िडयां : 2
#  फिक्ंिसग : 1
#  होउच्च्ंगा : 2
#  स्िवफ्ट : 1
#  काप्ी : 1
#  हम्ेब्रम : 1
#  केन््रदों : 2
#  ट््िवटर, : 1
#  ट््वीट : 1
#  स्ातकोत्तर : 2
#  छुट््टी : 2
#  सवाचर््च्च : 1
#  वष्ाोü : 3
#  एंड््रयू : 1
#  डिस्े : 2
#  चचऱ्ा : 1
#  शक्ित : 1
#  पोष्ााहार : 1
#  ब्रह्मभट््ट : 1
#  भ्ी : 4
#  आशीष्ा : 1
#  दिसम्ब्ार : 1
#  इक्जीक्ूयटिव : 1
#  भ्ौरव : 3
#  सघ्ांर्ष : 1
#  धब्ब्ाा : 1
#  आथर््िाक : 1
#  आउच्च्ंगा।’’ : 1
#  उज्ौन : 2
#  दागपुट्ट्ी : 1
#  चन््रद : 1
#  सट््टात्मक : 1
#  श्ौल : 1
#  शोष्ाण : 1
#  अन्वेष्ाण : 1
#  उच्च्ंची : 7
#  कोष्ा : 2
#  (इंस्ंिटक्ट) : 1
#  çब्ाछीवाड़ा : 1
#  शतोर्ं : 2
#  स्ेहलता : 1
#  çक्ंवटल : 1
#  हुईर्ं। : 1
#  प्रदश्ेा : 1
#  श्ाकर : 2
#  सख्ंयताओं : 1
#  ट्ेवल्स : 1
#  व्यक्ित : 1
#  कार्यकत्तर्ााओं-नेताओं : 1
#  उज्ौनिया : 1
#  भट््टाचार्यने : 1
#  दोçष्ायों : 3
#  सदर््यूकोव : 1
#  çब्ा्रटिश : 1
#  पोस्ंटिग : 1
#  परर्िवत्तनकारी : 1
#  प्रैक्िटस : 1
#  भट््ट : 3
#  मिट््टी : 13
#  परर्िवत्तन : 2
#  प््ररस्ताव : 1
#  वष्ाोüं : 1
#  शॉटर््स : 1
#  अड््डा : 1
#  खद््दरधारी : 1
#  नवम्ब्ार: : 2
#  व्यक्ितगत : 1
#  उल्ल्ेाखनीय : 1
#  बताउच्च्ंगा......यदि : 1
#  बताउच्च्ंगा : 1
#  मुक्ित : 1
#  हुड््डा : 2
#  ज्ौसा : 1
#  ख्ेाल : 1
#  शीष्ाü : 2
#  भत्तर्ाी : 1
#  शख़्स : 1
#  स्ेहा : 1
#  ब्ौंकों : 1
#  परफामर्ेंस : 1
#  मानुष्ा : 1
#  बज्ो : 1
#  अवशेष्ा : 1
#  मुट््ठी : 1
#  हैçब्ाटाट्स : 1
#  मुद््दा, : 1
#  दासमुंश्ी : 1
#  फमर्ाा : 3
#  नवम्ब्ार : 1
#  फिल्ंिडग : 2
#  औष्ाधालय : 1
#  ड््यूटी : 1
#  çब्ा्रज : 1
#  अब्ुदर : 1
#  इस्तीप्े : 2
#  संब्ाल : 1
#  ब्ा्रीड : 1
#  अद्धवाçष्ाüक : 1
#  आलच्ेच्य : 1
#  वक़्त : 14
#  हटर््ज : 3
#  इंस्टिट््यूट : 1
#  भतर््सना : 1
#  कृष्ण्ौया : 1
#  कट््टरपंथी : 1
#  पोस्ंिटग : 1
#  वगोर्ं : 1
#  भूख्ाड : 1
#  क्िवजाट, : 1
#  स्पोटर््स : 2
#  प्रतिवष्ाü : 1
#  पदाथोर्ं : 1
#  कम्युनिकेश्ांस, : 1
#  मेगाहटर््ज : 1
#  ख्ेाला। : 1
#  नरेन््रद : 2
#  संघष्ाü : 4
#  द्वेष्ाता : 1
#  दर्ुव्यवहार : 2
#  चिट््ठी : 1
#  पट््टे : 1
#  फ्ेड : 1
#  ‘उद््घाटनों, : 1
#  पुरूष्ा-महिलाएं : 1
#  भीष्ाण : 1
#  औष्ाधि : 1
#  दिसम्ंबर : 1
#  प्रबध्ंाक : 1
#  द््यूरास : 1
#  श्ांभु : 1
#  सुखिऱ्यों : 1
#  कंट््रोल : 1
#  दूçष्ात : 1
#  उल्ल्ेाख : 1
#  थ्ौरेपी : 1
#  वष्ााüें : 1
#  स्ेह, : 1
#  च्े : 1
#  हष्ाü : 1
#  भूष्ाण : 1
#  पद््म : 1
#  नसीरुद््दीन : 1
#  हेमस्ंिट्रग : 1
#  माद््दा : 1
#  आध्ुनिक : 3
#  निदर्ेशित : 1
#  निदर्ेशक : 20
#  रूप्ा : 4
#  ग्ुारुत्वाकर्षण : 1
#  तीव््राता : 3
#  पदाथर्ों : 1
#  श्ोयरधारकोंं : 1
#  औकर्ुट : 1
#  निदर्ेशकों : 10
#  निदर्ेशन : 1
#  ख्ुालता : 1
#  फ्लेक्िसबिलिटी : 1
#  दफ़्तर..... : 1
#  ध्ंध्े : 2
#  गांध्ी : 3
#  सस्ंकृतियों : 1
#  भट््टाचार्य : 3
#  ‘टर्र्र््रेक्टर : 1
#  रूपेण्ा : 1
#  क्ार्यालय : 1
#  ज़्यादातर : 1
#  धमोर्ं : 2
#  सवर्ोच्चता : 1
#  घ्ाायल : 1
#  गांध्ीवादी : 2
#  गांध्ीवादियों : 1
#  स्क्ूल : 1
#  अर्ंतात्मा : 1
#  ठ्ठ्ठ््ठाक, : 1
#  ध्ूर्त : 1
#  इंस्ट्ीटयूट : 1
#  उत्तराख्ंड : 3
#  रविन््रद : 1
#  निश्ंिचत : 5
#  कफर््यू’ : 1
#  रुक़्न : 1
#  नक़्क़ाद : 1
#  मुगऱ्ी : 1
#  पुनर्ःलिखे : 1
#  निश्ंिचतता : 1
#  मुदद्े : 1
#  विरोध्ी : 4
#  घ्ाोर : 1
#  ट्ांसफर : 1
#  बार्ंबार : 1
#  अंतर्राष्ट्र्ीय : 2
#  कांग्ेस : 1
#  क्ुल : 1
#  ज़्यादा। : 1
#  ट्ांसपरेंसी : 1
#  नज़्ााकत : 1
#  ख्ुाशियोंे : 1
#  ब्ा्रह्म : 5
#  तरक़्क़ी : 1
#  इनक़्लाब : 1
#  शेड््स : 1
#  ल्ेकिन : 4
#  स्ंातान : 1
#  घ्ाटनाओं : 3
#  बश्ंाकार : 1
#  राध्ेाश्याम : 1
#  रेडड्ी : 1
#  धनाड््यों : 1
#  राबटर््सगंज, : 1
#  ख्ंिाच : 1
#  श्ुाबा : 2
#  ज्ुाबान : 1
#  ध़्ाड : 1
#  गुगोर्ं : 1
#  बंध्ंध्यो : 1
#  प्ंाद्रह : 1
#  इण्डस्ट्ीज : 1
#  बेइज़्ज़त : 1
#  ड्ाइंगरूम : 1
#  अब्ब्ूा : 1
#  रक़्स : 1
#  बंध्ंधे,े,जाके : 1
#  श्ंकर : 1
#  भट््टा : 1
#  आख्ािर : 1
#  बेरोज्ागार : 1
#  हाउसेज्ा : 1
#  कुत्ुत्तों : 1
#  घ्ोरा : 1
#  घ्ोर : 1
#  राग-द्वेष्ा : 1
#  हुक़्म : 1
#  ड्ाईवर : 1
#  1.धमर्ेंद्र : 1
#  ज्योतिष्ााचार्य। : 1
#  ग्ंगा : 1
#  उम््रा : 2
#  श्ंाकर : 1
#  दुव्घर््यवहार, : 1
#  ‘‘ग्ंगाजल : 1
#  जीवन.संघषर्ों : 1
#  इज़्ज़त : 1
#  छुट््टी!दस : 1
#  नक़्श : 1
#  संघषर्् : 1
#  निबर्ुद्धि : 1
#  र्ंगीली : 1
#  अद््भुत : 1
#  उद्ेश्य : 1
#  ख््राुश्चेव : 1
#  म्ुनिरका- : 1
#  अर्थशास़्ित्रयों : 1
#  उम्म्ीदवार : 1
#  मैजिस्ट्ेट : 3
#  प्रश्ंवाचक : 1
#  ख्ूाब : 1
#  स्ंवय : 2
#  हज्ज्ज्ज्ाार : 1
#  थ्ो : 1
#  राष्ट्ीय : 2
#  ध्ंाधे : 1
#  लोहापट््टी : 1
#  ढ्ँढ़ : 1
#  घ्ंटे : 1
#  थ्ीा : 1
#  पुर्षाथर््ा : 1
#  प्र्िरतिषत : 1
#  दजऱ् : 1
#  ट्ेनिंग : 1
#  गड़्मड़ : 1
#  ख्ुादाई : 1
#  पचांर्े : 1
#  सास्ंकृतिक : 1
#  प््रायासों : 1
#  प््रासिद्ध : 1
#  प््रााविडेंट : 1
#  परमश्ेवर! : 1
#  ...‘पेैड्ो’ : 1
#  छिन्न-भिन्ेन : 1
#  त्ंज़ीम : 1
#  अक़्ली : 2
#  वैन्ैन्ट : 1
#  क्लियोपेट्ा, : 1
#  प्राब्ॅलम : 1
#  बशतर्े : 1
#  प्ाशुपालन : 1
#  क़ब्ज़्ाा : 1
#  सीध्े : 1
#  स्व्ीकार : 2
#  ेष्ेष्य : 1
#  मिट््टी, : 1
#  अत्ंयत : 1
#  अंतर्राष्ट्ीय : 1
#  अट्ाहास : 1
#  पेट्ोल : 1
#  न्यूट्ीषिन : 1
#  ‘दूध्ूध’ : 1
#  लम्ऽऽबी : 1
#  देशबंध्ुा : 1
#  घ्ाटित : 1
#  घ्ार : 1
#  पाशर््व : 1
#  प्रश्ंचिन्ह : 1
#  ऑपॅपरेष्ेषन’ : 1
#  देश्ी : 1
#  सेष्ी : 1
#  विमशर््ा’ : 1
#  प्राण-वाक्् : 1
#  सुब्रह््मण्यम : 1
#  मजिस्ट्ेट : 1
#  निश्ंचितता : 1
#  महामंत्र्ी : 1
#  दूध्ूध : 1
#  मनीष्ाी : 1
#  नक़्क़ादों : 1
#  है.निदर्ेशक : 1
#  गांध्ी, : 1
#  शक़्लें : 1
#  बुजष्ुर्ग : 1
#  ट्ंासफर : 1
#  प््राषिक्षण : 1
#  प््राषासन : 1
#  बहुस्ंस्कृतिवाद : 1
#  वर्चसर््स्व : 1
#  कफर््यू : 1
#  शक़्ल : 1
#  नुक़्ते : 1
#  क्ष्े. : 1
#  रिकाडऱ्स : 1
#  बच्च्े : 1
#  पावरलिफ्ंिटग : 1
#  वषर्ों : 1
#  पूणर््ातय: : 1
#  ध्ार्मेंद्र, : 1
#  ख्ेाली : 1
#  च्ंद्र : 1
#  इलेक्ट्ानिक : 1
#  इंटरप््रााईजेज : 1
#  घ्ाुसाया : 1
#  श्ंाख : 1
#  देख्ेा : 1
#  उपाध्ि : 1
#  मिजऱ्ापुर : 1
#  वषोर्ं : 1
#  छ्ःओटी : 1
#  प्रा्रोत्ेत्साहित : 1
#  पालन-पोष्ाण : 1
#  (ब्ा्रह्म) : 1
#  विध्ेयक : 1
#  कलारूप्ा : 1
#  मैंट्ो : 1
#  राष्ट्र्ीय : 1
#  एफटर््स : 1
#  ज़्पारोशिया : 1

# %%
def isValidWord():
    pass

# %%
def isEndOfLine(x):
    if u'\u0964' <= x <= u'\u0965' :
        return True
    return False
    

def isMatra(x):
    if (u'\u0901' <= x <= u'\u0903' or 
        u'\u093C' <= x <= u'\u094F' or
        u'\u0951' <= x <= u'\u0954' or
        u'\u0951' <= x <= u'\u0954' or
        u'\u0962' <= x <= u'\u0963'):
        return True
    return False
def isVowel(x):
    if (u'\u0905' <= x <= u'\u0914' or 
        u'\u0960' <= x <= u'\u0961'):
        return True
    return False
def isConsonant(x):
    if (u'\u0915' <= x <= u'\u0939' or 
        u'\u0958' <= x <= u'\u095F'):
        return True
    return False

def isOM(x):
    if x == u'\u0950' :
        return True
    return False

# %%
sample = 'येदयुरप्पा, उनके बेटे और सांसद बी वाई राघवेन्द्र, बी वाई विजयेन्द्र, दामाद आर एन सोहन कुमार कोर्ट में मौजूद थे। कोर्ट ने 16 नवंबर को इन्हें मौजूद होने के लिए समन जारी किया था। अदालत ने यह भी कहा कि मामले में जांच खत्म हो चुकी है।'
sample.split()[7]
# Out:
# 'राघवेन्द्र,'

# %%
detectChars = {}

def detectCharsFunc(word):
    chars = list(word) 
    a = ''
    enum_iter = enumerate(chars)
    flag = 0
    for index, char in enum_iter:
         if(isVowel(char) or isConsonant(char)):
            flag=0
            if a is not '':
                if a in detectChars: 
                    detectChars[a] += 1
                else: 
                    detectChars.update({a: 1})
            a = char
        elif(isMatra(char)):
            a += char
            if char==u'\u094D':
                flag += 1
                if flag>1:
                    flag = 0
                    while (index+1 < len(chars) and  isMatra(chars[index+1])):
                        index, char = next(enum_iter)
                        a += char
                    if a in detectChars: 
                        detectChars[a] += 1
                    else: 
                        detectChars.update({a: 1})
                    a = ''
                    continue

                if (index+1 >= len(chars)):
                    continue
                index, char = next(enum_iter)
                a += char
            else:
                flag = 0
    if a in detectChars: 
        detectChars[a] += 1
    else: 
        detectChars.update({a: 1})    
detectCharsFunc(word)
detectChars
# Out:
# {'का': 1}

# %%
for para in new_sample:
    words = para.split()
    for word in words:
        detectCharsFunc(word)

# %%
detectChars
# Out:
# {'का': 480299,
#  'पू': 50976,
#  'र्व': 16032,
#  'पा': 117684,
#  'कि': 334466,
#  'स्ता': 16760,
#  'नी': 128448,
#  'क': 1004802,
#  'प्ता': 4770,
#  'न': 861356,
#  'अ': 398585,
#  'र': 1678224,
#  'म': 490531,
#  'ने': 525971,
#  'हा': 174750,
#  'य': 315376,
#  'दि': 135408,
#  'खि': 26443,
#  'ला': 183515,
#  'ड़ी': 7293,
#  'द': 289819,
#  'बा': 178825,
#  'व': 319186,
#  'भू': 15773,
#  'ल': 523101,
#  'ना': 285709,
#  'भी': 183297,
#  'चा': 98785,
#  'हे': 53772,
#  'तो': 96557,
#  'र्श': 10532,
#  'क्रि': 9769,
#  'के': 607038,
#  'ट': 147478,
#  'प्रे': 10525,
#  'मी': 41619,
#  'औ': 205570,
#  'डि': 25526,
#  'या': 333037,
#  'ऐ': 33944,
#  'सा': 199281,
#  'हीं': 131952,
#  'दे': 142700,
#  'ता': 291282,
#  'है': 403619,
#  'उ': 300196,
#  'न्हों': 26127,
#  '': 292187,
#  'लो': 63966,
#  'ग': 373410,
#  'ह': 536967,
#  'ते': 148860,
#  'हैं': 148278,
#  'ए': 385961,
#  'शे': 13916,
#  'ज': 327405,
#  'में': 410243,
#  'ब': 431980,
#  'हु': 94677,
#  'त': 516523,
#  'हो': 185855,
#  'ले': 198283,
#  'भा': 99596,
#  'मै': 17475,
#  'चों': 1632,
#  'जि': 73505,
#  'सी': 114467,
#  'न्य': 14413,
#  'थ': 65813,
#  'खे': 18177,
#  'इ': 270253,
#  'च्छा': 7269,
#  'प्र': 128754,
#  'मा': 201340,
#  'र्के': 1113,
#  'क्स': 12112,
#  'फो': 7283,
#  'लि': 161217,
#  'टिं': 3520,
#  'प': 632892,
#  'स्क्': 1196,
#  'आ': 322080,
#  'से': 368859,
#  'मि': 86458,
#  'जा': 216889,
#  'एं': 21803,
#  'गे': 48836,
#  'च्चों': 5113,
#  'मु': 84659,
#  'ब्रि': 2528,
#  'स': 817892,
#  'वा': 212906,
#  'ब्र': 2779,
#  'श': 167234,
#  'को': 306806,
#  'गो': 15121,
#  'ई': 184307,
#  'घु': 3932,
#  'रें': 18061,
#  'र्वी': 641,
#  'कै': 16770,
#  'र्ग': 8767,
#  'सं': 93296,
#  'त्ति': 4128,
#  'लं': 9395,
#  'बे': 33422,
#  'ती': 132797,
#  'मौ': 17356,
#  'जू': 15266,
#  'दा': 96967,
#  'जी': 67073,
#  'शै': 2025,
#  'ली': 85437,
#  'झौ': 1190,
#  'हि': 61417,
#  'रे': 117993,
#  'नि': 128361,
#  'वे': 46831,
#  'री': 181968,
#  'कु': 65384,
#  'छ': 63723,
#  'रि': 102659,
#  'र्न': 2705,
#  'की': 393149,
#  'द्रा': 2088,
#  'स्फी': 258,
#  'ति': 108681,
#  'हं': 6180,
#  'गा': 109378,
#  'धि': 40165,
#  'ही': 164457,
#  'सृ': 1122,
#  'था': 90673,
#  'गी': 55657,
#  'किं': 3416,
#  'ड': 65924,
#  'र्स': 6704,
#  'पॉ': 2437,
#  'बें': 1421,
#  'ढ़ी': 2360,
#  'कें': 9203,
#  'कं': 15735,
#  'जे': 21166,
#  'रो': 66462,
#  'लिं': 3205,
#  'खा': 56484,
#  'सें': 4392,
#  'सि': 51554,
#  'प्लै': 108,
#  'फॉ': 1914,
#  'र्म': 16333,
#  'ब्ध': 2786,
#  'हों': 12299,
#  'शु': 25438,
#  'रु': 37351,
#  'शि': 40847,
#  'वी': 20385,
#  'रू': 53763,
#  'द्द': 1453,
#  'रा': 252352,
#  'ग्रा': 7701,
#  'ण': 74212,
#  'पु': 50721,
#  'ड़ू': 124,
#  'पो': 14489,
#  'ऊ': 9271,
#  'ढ़': 16118,
#  'शा': 59198,
#  'मं': 44889,
#  'बि': 40846,
#  'बै': 17783,
#  'च': 147620,
#  'म्बा': 888,
#  'ध': 62335,
#  'ठा': 14773,
#  'लां': 6620,
#  'ल्लू': 655,
#  'डी': 21708,
#  'घा': 6897,
#  'सुं': 1462,
#  'कां': 15997,
#  'पि': 27977,
#  'ओ': 31071,
#  'सो': 27261,
#  'घ': 37471,
#  'टी': 40693,
#  'र्ण': 12677,
#  'बं': 25210,
#  'दी': 61792,
#  'मां': 15676,
#  'जु': 15845,
#  'लू': 8829,
#  'तृ': 4417,
#  'त्व': 11367,
#  'क्ट्': 2235,
#  'हुं': 11952,
#  'चे': 17944,
#  'थे': 36793,
#  'फ्फ': 402,
#  'नों': 39689,
#  'क्टि': 727,
#  'वै': 13498,
#  'भ': 63124,
#  'ट्ठि': 151,
#  'यों': 57379,
#  'ढा': 2886,
#  'क्ष': 34079,
#  'ढ़ा': 8684,
#  'पी': 38181,
#  'गों': 24147,
#  'यी': 20892,
#  'थी': 41339,
#  'डूं': 118,
#  'नु': 28278,
#  'फ़ी': 1093,
#  'र्मि': 4041,
#  'ल्ला': 3174,
#  'र्मा': 9869,
#  'स्थि': 14122,
#  'प्रा': 16997,
#  'धा': 46502,
#  'क्त': 18010,
#  'फ्रं': 168,
#  'छो': 15705,
#  'ड़': 46599,
#  'श्य': 6882,
#  'र्धा': 1762,
#  'ल्क': 1391,
#  'ल्ली': 10287,
#  'गु': 29607,
#  'दं': 3583,
#  'ख्य': 10576,
#  'त्री': 21353,
#  'द्र': 13080,
#  'मो': 24770,
#  'ख': 116117,
#  'ड़े': 6481,
#  'फ': 54740,
#  'भं': 1988,
#  'ट्ट': 1080,
#  'सु': 55348,
#  'प्री': 3086,
#  'र्ट': 15055,
#  'शी': 19031,
#  'र्ष': 14471,
#  'ट्रा': 1177,
#  'मे': 67721,
#  'स्टे': 4391,
#  'र्थ': 14704,
#  'अं': 30487,
#  'न्यु': 267,
#  'लॉ': 2487,
#  'र्च': 6493,
#  'क्ति': 17049,
#  'ऑ': 9899,
#  'क्सि': 409,
#  'डें': 1720,
#  'फा': 16479,
#  'स्ट': 15570,
#  'जॉ': 1168,
#  'र्पी': 7,
#  'दू': 32622,
#  'सौ': 5775,
#  'त्या': 8090,
#  'त्थी': 95,
#  'झी': 1318,
#  'यें': 5037,
#  'ष्ट्': 13593,
#  'फै': 10291,
#  'न्या': 8629,
#  'बी': 41072,
#  'जां': 6078,
#  'पां': 7963,
#  'रों': 34528,
#  'स्या': 5201,
#  'वि': 152965,
#  'श्व': 11827,
#  'व्या': 6221,
#  'तै': 9164,
#  'दो': 45812,
#  'तं': 10451,
#  'त्रों': 7548,
#  'प्रौ': 432,
#  'द्यो': 3278,
#  'गि': 18338,
#  'स्तां': 217,
#  'त्त': 12313,
#  'ड़ा': 20116,
#  'यो': 35168,
#  'म्मे': 4485,
#  'तौ': 6424,
#  'जो': 49296,
#  'लों': 22398,
#  'फ्री': 1566,
#  'टे': 26139,
#  'द्वी': 757,
#  'शों': 5329,
#  'ल्प': 5161,
#  'ची': 20205,
#  'म्यु': 792,
#  'र्टी': 9950,
#  'र्क': 8643,
#  'कों': 20599,
#  'वृ': 5655,
#  'क्षा': 17720,
#  'ड़ी': 18446,
#  'स्का': 3544,
#  'उं': 3845,
#  'ये': 78243,
#  'क्ज': 55,
#  'यां': 13062,
#  'ब्ल्': 690,
#  'यू': 11812,
#  'र्सि': 1107,
#  'मॉ': 1844,
#  'रं': 16241,
#  'र्भ': 2884,
#  'जिं': 4318,
#  'बां': 4508,
#  'ग्ला': 1076,
#  'पिं': 1527,
#  'द्वि': 1465,
#  'क्षी': 2094,
#  'ष': 30538,
#  'र्चा': 4646,
#  'तें': 6950,
#  'खें': 4587,
#  'ज्य': 10944,
#  'स्कू': 5210,
#  'ट्रे': 2904,
#  'धी': 18275,
#  'र्ती': 1786,
#  'ग्री': 2633,
#  'ध्य': 15243,
#  'स्थ': 4292,
#  'ल्द': 2250,
#  'म्मी': 6235,
#  'दौ': 15548,
#  'ठ': 32093,
#  'गिं': 543,
#  'खों': 4842,
#  'बैं': 6169,
#  'ल्ट': 898,
#  'फि': 45066,
#  'भो': 6236,
#  'क्ता': 3154,
#  'ओं': 31198,
#  'ब्या': 1174,
#  'ऋ': 2112,
#  'स्तें': 24,
#  'चु': 30082,
#  'द्या': 5663,
#  'फी': 16060,
#  'ढ़ा': 1641,
#  'बो': 21783,
#  'र्ड': 9287,
#  'ब्यो': 175,
#  'पे': 21268,
#  'न्हें': 20141,
#  'म्र': 3769,
#  'दु': 25973,
#  'कॉ': 8559,
#  'क्श': 2540,
#  'स्क': 2647,
#  'कैं': 1991,
#  'स्तों': 1224,
#  'थो': 5404,
#  'णा': 11726,
#  'झे': 16877,
#  'मैं': 34259,
#  'तों': 11154,
#  'धों': 1675,
#  'स्त': 20830,
#  'च्छी': 3629,
#  'रॉ': 1766,
#  'ख्या': 7162,
#  'डे': 11709,
#  'लौ': 5151,
#  'स्टैं': 469,
#  'ठी': 8481,
#  'स्प': 8315,
#  'ष्ट': 7229,
#  'म्हों': 100,
#  'छा': 13878,
#  'ट्वी': 314,
#  'च्च': 3745,
#  'ख्स': 572,
#  'न्ना': 6785,
#  'ब्द': 2712,
#  'क्या': 23915,
#  'टा': 26158,
#  'पै': 15398,
#  'न्त': 3710,
#  'सू': 24844,
#  'नं': 7797,
#  'श्र': 5180,
#  'यु': 19725,
#  'र्षी': 1441,
#  'डो': 3330,
#  'नू': 7466,
#  'गं': 8484,
#  'र्र': 3252,
#  'रिं': 2110,
#  'बू': 11978,
#  'ड़': 18161,
#  'टू': 5417,
#  'ड़ा': 7454,
#  'झ': 20129,
#  'भि': 16233,
#  'द्वा': 13317,
#  'न्न': 9398,
#  'जें': 4519,
#  'गृ': 2530,
#  'त्रा': 9227,
#  'र्त': 6240,
#  'स्व': 14665,
#  'खु': 21859,
#  'ग्र': 8454,
#  'चि': 24675,
#  'चं': 5531,
#  'र्या': 5601,
#  'प्त': 9296,
#  'द्री': 2285,
#  'वों': 4558,
#  'र्दे': 4157,
#  'श्चि': 4748,
#  'त्र': 43096,
#  'फें': 1311,
#  'क्रे': 1266,
#  'णे': 1537,
#  'थि': 6842,
#  'र्य': 22825,
#  'र्ता': 4557,
#  'हां': 29038,
#  'ल्म': 10928,
#  'ढ़े': 2274,
#  'ऊं': 3617,
#  'शं': 4506,
#  'व्य': 24003,
#  'स्था': 24911,
#  'स्वी': 5691,
#  'र्फ': 7643,
#  'ल्कि': 4984,
#  'कृ': 11677,
#  'षि': 5194,
#  'क्षे': 11698,
#  'र्जी': 4367,
#  'सिं': 19010,
#  'ग्य': 3327,
#  'गें': 4636,
#  'शो': 9950,
#  'ख्त': 1161,
#  'ब्ला': 1026,
#  'टि': 15099,
#  'प्प': 2235,
#  'णि': 3769,
#  'थों': 2298,
#  'क्ला': 1687,
#  'च्छे': 2617,
#  'छी': 1202,
#  'क्य': 574,
#  'णी': 6161,
#  'ग्रे': 13572,
#  'स्लि': 1728,
#  'हिं': 8211,
#  'ड़ों': 1275,
#  'श्या': 1224,
#  'म्मू': 668,
#  'श्मी': 1334,
#  'खं': 4988,
#  'जों': 4690,
#  'चो': 4892,
#  'भ्र': 6466,
#  'ष्टा': 4796,
#  'चू': 2890,
#  'डा': 22623,
#  'पं': 11474,
#  'गां': 12268,
#  'चौ': 8273,
#  'ग्रि': 571,
#  'तु': 33930,
#  'नुु': 3,
#  'छे': 6821,
#  'खो': 10021,
#  'त्वों': 494,
#  'ऩे': 772,
#  'डि़': 631,
#  'घ्र': 754,
#  'र्थि': 5127,
#  'स्टा': 3346,
#  'ल्टी': 1162,
#  'ल्ड': 2502,
#  'प्रो': 5386,
#  'लें': 8829,
#  'लै': 1775,
#  'प्ला': 1940,
#  'स्टी': 1497,
#  'स्ड': 191,
#  'ट्रि': 702,
#  'मिं': 660,
#  'मू': 14894,
#  'निं': 2233,
#  'र्ट्': 573,
#  'फ्रे': 422,
#  'श्यू': 113,
#  'ल्मों': 2565,
#  'म्प्': 1162,
#  'विं': 2402,
#  'भां': 883,
#  'लॉं': 21,
#  'र्ल्': 775,
#  'चै': 4546,
#  'क्र': 13055,
#  'ज्या': 12324,
#  'आं': 11544,
#  'छि': 2795,
#  'मों': 5196,
#  'र्शि': 939,
#  'ब्स': 275,
#  'प्श': 608,
#  'स्ते': 6107,
#  'त्ता': 6036,
#  'ज्ञा': 10633,
#  'त्म': 8924,
#  'हौ': 2496,
#  'स्तं': 220,
#  'फे': 7718,
#  'र्ज': 9465,
#  'थु': 804,
#  'द्य': 2329,
#  'ड़ि': 2651,
#  'शू': 2255,
#  'ञ्च': 93,
#  'र्वा': 3073,
#  'श्ले': 665,
#  'षा': 6857,
#  'इं': 24131,
#  'शिं': 896,
#  'र्चों': 179,
#  'नौ': 8276,
#  'क्षि': 6182,
#  'र्जा': 2682,
#  'त्नी': 3516,
#  'थीं': 4801,
#  'झू': 2384,
#  'ठे': 5460,
#  'दों': 5276,
#  'जै': 20093,
#  'श्री': 9206,
#  'स्मि': 762,
#  'श्रा': 1334,
#  'मृ': 4584,
#  'डु': 1386,
#  'वं': 15556,
#  'रां': 3065,
#  'ब्लू': 330,
#  'र्ा': 12,
#  'लु': 4687,
#  'बिं': 1111,
#  'च्छ': 1002,
#  'यं': 8734,
#  'क्ट': 8782,
#  'झा': 10294,
#  'ज्यों': 2252,
#  'हू': 3504,
#  'ष्ठ': 4280,
#  'सां': 6486,
#  'य्य': 179,
#  'स्ती': 3721,
#  'ष्ाी': 19,
#  'ट्रो': 2658,
#  'क्यों': 15971,
#  'छू': 3097,
#  'श्वे': 508,
#  'खी': 7993,
#  'रौ': 1095,
#  'चां': 1879,
#  'ख्यि': 64,
#  'ब्यू': 945,
#  'ड़ों': 3088,
#  'त्त्': 654,
#  'ट्ठी': 718,
#  'त्रि': 8805,
#  'स्ट्': 5574,
#  'ण्णा': 159,
#  'नीं': 1902,
#  'ब्ब': 1568,
#  'ष्ण': 2860,
#  'र्ति': 4038,
#  'स्रो': 488,
#  'ाी': 7,
#  'क्वि': 356,
#  'स्चा': 21,
#  'गू': 3709,
#  'ड़े': 16320,
#  'स्य': 4504,
#  'डिं': 948,
#  'पों': 2442,
#  'कौ': 6765,
#  'हूं': 10421,
#  'क्से': 495,
#  'प्ट': 1019,
#  'श्कि': 2736,
#  'प्रॉ': 1031,
#  'ब्ल': 678,
#  'भे': 7573,
#  'श्वि': 1213,
#  'र्दा': 919,
#  'श्त': 982,
#  'स्सा': 3999,
#  'हें': 6789,
#  'ग्लैं': 1259,
#  'र्भी': 88,
#  'र्वे': 2233,
#  'न्द्': 6813,
#  'पृ': 2059,
#  'थ्वी': 1094,
#  'प्रै': 1603,
#  'र्णा': 473,
#  'बों': 2091,
#  'डॉ': 7465,
#  'र्डिं': 194,
#  'भु': 4405,
#  'त्य': 8957,
#  'त्ती': 2726,
#  'डों': 1137,
#  'ढ़ो': 857,
#  'ल्ले': 4160,
#  'वां': 1676,
#  'चिं': 3956,
#  'ष्य': 4843,
#  'स्त्': 6595,
#  'न्': 850,
#  'त्यु': 1604,
#  'स्वा': 9053,
#  'स्थ्': 2327,
#  'च्चे': 5084,
#  'ढ़ी': 579,
#  'ठीं': 95,
#  'नैं': 218,
#  'न्हि': 110,
#  'सै': 5993,
#  'द्धां': 1283,
#  'र्षों': 1657,
#  'ड़़ें': 1,
#  'क्सा': 562,
#  'बु': 19840,
#  'ल्डिं': 417,
#  'ब्रॉ': 157,
#  'ग्रु': 1033,
#  'र्कि': 742,
#  'दें': 5342,
#  'घं': 3516,
#  'टों': 3875,
#  'प्पी': 513,
#  'धे': 7195,
#  'ढ़ो': 165,
#  'ढु': 124,
#  'म्ब': 5199,
#  'ठि': 3661,
#  'ठु': 514,
#  'र्दी': 728,
#  'ल्की': 391,
#  'ठं': 1273,
#  'धू': 3575,
#  'र्द': 5106,
#  'न्यू': 3949,
#  'ल्सि': 288,
#  'फ़ो': 745,
#  'शॉ': 839,
#  'क्के': 971,
#  'फ्ट': 1392,
#  'क्नी': 73,
#  'ढ': 5378,
#  'क्री': 1851,
#  'ट्ठा': 445,
#  'षों': 1124,
#  'स्ति': 2308,
#  'ष्क': 1453,
#  'ध्या': 8157,
#  'न्टें': 26,
#  'गै': 5298,
#  'ण्ड': 2870,
#  'द्धि': 4358,
#  'ऎ': 805,
#  'क्ष्': 4477,
#  'ब्सि': 783,
#  'गौ': 4656,
#  'र्ना': 1899,
#  'फ्ता': 3705,
#  'म्द': 11,
#  'वो': 16677,
#  'ट्ज': 170,
#  'भ्या': 727,
#  'श्रे': 2646,
#  'वीं': 2343,
#  'रैं': 572,
#  'फ्रें': 962,
#  'डू': 2141,
#  'प्ले': 1586,
#  'र्टि': 1832,
#  'ढं': 1450,
#  'नॉ': 1177,
#  'मुं': 6315,
#  'र्किं': 513,
#  'म्पि': 563,
#  'प्यू': 877,
#  'घो': 7260,
#  'ल्कु': 1291,
#  'णों': 3964,
#  'टो': 7035,
#  'धं': 698,
#  'ग्ध': 666,
#  'श्चा': 819,
#  'भुं': 52,
#  'द्ध': 9195,
#  'धो': 2666,
#  'वु': 1909,
#  'ब्वे': 45,
#  'यौ': 743,
#  'त्पी': 363,
#  'ब्बी': 131,
#  'खू': 4743,
#  'सैं': 696,
#  'टैं': 325,
#  'जुं': 123,
#  'र्पि': 961,
#  'नै': 3647,
#  'ड़ो': 422,
#  'ल्स': 2292,
#  'स्पॉ': 199,
#  'क्सिं': 177,
#  'स्पि': 1241,
#  'ल्वे': 106,
#  'स्ली': 275,
#  'र्नी': 326,
#  'ल्शि': 143,
#  'ज़': 11950,
#  'नें': 3979,
#  'झो': 1028,
#  'ईं': 2907,
#  'कू': 4906,
#  'र्मो': 326,
#  'हॉ': 2190,
#  'च्यू': 78,
#  'नो': 12603,
#  'र्षि': 1188,
#  'त्फ': 118,
#  'वें': 3097,
#  'न्वे': 320,
#  'म्।': 163,
#  'शां': 4094,
#  'र्डों': 77,
#  'झं': 871,
#  'बॉ': 3674,
#  'ल्यों': 479,
#  'फ़ा': 1213,
#  'ब्बा': 680,
#  'फ़ें': 60,
#  'षी': 1870,
#  'ट्टा': 1067,
#  'र्फ्': 121,
#  'सौं': 2252,
#  'घू': 2223,
#  'द्धृ': 81,
#  'फ़ि': 2910,
#  'न्स': 1189,
#  'ल्यू': 479,
#  'द्भु': 447,
#  'ड्रा': 2010,
#  'फैं': 297,
#  'ट्रै': 1163,
#  'र्घ': 1190,
#  'फ़ु': 122,
#  'क्ल': 1782,
#  'स्री': 20,
#  'पें': 1698,
#  'ड्रे': 821,
#  'ल्व': 307,
#  'प्रि': 3323,
#  'र्पो': 254,
#  'कुं': 2203,
#  'स्यों': 1662,
#  'ह्रीं': 40,
#  'त्ते': 1413,
#  'ट्टे': 515,
#  'क्लिं': 176,
#  'क्लि': 700,
#  'खिं': 431,
#  'द्रो': 965,
#  'सों': 3674,
#  'क्षों': 729,
#  'द्रि': 755,
#  'स्मा': 1187,
#  'छूं': 47,
#  'पौ': 1718,
#  'तू': 4338,
#  'द्धु': 11,
#  'त्\u200d': 1643,
#  'ग्वि': 493,
#  'ग्रो': 396,
#  'र्सें': 311,
#  'न्ज': 102,
#  'ड्यू': 778,
#  'ड्स': 945,
#  'ड्रॉ': 302,
#  'फ्यू': 276,
#  'क्नो': 235,
#  'भौं': 235,
#  'श्तों': 724,
#  'ल्कों': 104,
#  'ज्व': 252,
#  'द्धा': 2220,
#  'स्कृ': 3328,
#  'ध्व': 866,
#  'झु': 1892,
#  'न्द': 7217,
#  'म्दा': 136,
#  'भौ': 1000,
#  'श्रृं': 718,
#  'ष्प': 718,
#  'ल्य': 2006,
#  'दृ': 4434,
#  'ष्टि': 3812,
#  'क्रा': 1331,
#  'ज्ज्ाि': 9,
#  'ण्य': 892,
#  'ण्यों': 23,
#  'न्तु': 2874,
#  'त्न': 858,
#  'र्भा': 821,
#  'ल्या': 1660,
#  'म्प': 3692,
#  'ढ़': 3671,
#  'र्शा': 620,
#  'थॉ': 288,
#  'धु': 5725,
#  'त्पा': 2984,
#  'ण्डी': 249,
#  'थै': 312,
#  'ग्गी': 179,
#  'स्ना': 1029,
#  'क्षु': 453,
#  'श्ली': 385,
#  'ट्यू': 941,
#  'घि': 2514,
#  'हृ': 1396,
#  'म्मा': 3934,
#  'प्ल': 274,
#  'श्क': 845,
#  'म्म': 3262,
#  'चें': 1326,
#  'बृ': 456,
#  'ल्लं': 592,
#  'ब्दों': 1507,
#  'छु': 3804,
#  'भै': 870,
#  'ज्ज': 1045,
#  'त्का': 3380,
#  'क्वा': 1028,
#  'ज्वा': 588,
#  'प्पा': 734,
#  'रूं': 1084,
#  'ब्जी': 459,
#  'क्क': 3214,
#  'दूं': 937,
#  'द्दे': 4089,
#  'ख्सी': 35,
#  'ब्रां': 836,
#  'र्सा': 72,
#  'ल्में': 1367,
#  'कीं': 530,
#  'र्डि': 270,
#  'वॉ': 1394,
#  'त्स्': 166,
#  'त्सा': 2702,
#  'ढी': 763,
#  'न्हो': 930,
#  'न्हा': 1555,
#  'त्रु': 711,
#  'ध्न': 11,
#  'फु': 2951,
#  'स्सी': 540,
#  'र्जं': 4,
#  'श्मा': 338,
#  'तीं': 1550,
#  'टै': 3020,
#  'शें': 601,
#  'स्ला': 1695,
#  'बूं': 454,
#  'जं': 3338,
#  'स्म': 2682,
#  'स्फो': 831,
#  'ल्ब': 210,
#  'क्का': 1834,
#  'ध्दि': 266,
#  'ब़': 37,
#  'डां': 900,
#  'र्शी': 962,
#  'र्सी': 856,
#  'ढे': 1437,
#  'त्स': 2241,
#  'भें': 608,
#  'ड़ि': 1871,
#  'क्शी': 30,
#  'स्तु': 3802,
#  'ल्पि': 318,
#  'क्च': 758,
#  'र्ड्': 169,
#  'यि': 4174,
#  'ढ़ि': 221,
#  'र्जु': 1137,
#  'ग्रं': 572,
#  'र्प': 1538,
#  'स्स': 177,
#  'द्घा': 501,
#  'खौ': 520,
#  'ख्ति': 197,
#  'ग्यू': 42,
#  'लैं': 2454,
#  'ट्र': 1807,
#  'स्से': 2358,
#  'र्ल': 774,
#  'णु': 1447,
#  'स्टं': 188,
#  'ऱ': 16,
#  'क्रां': 1302,
#  'र्बा': 784,
#  'तां': 1344,
#  'स्टों': 321,
#  'न्हीं': 1818,
#  'ख्ता': 434,
#  'श्ते': 1677,
#  'स्ने': 569,
#  'टौ': 813,
#  'द्दी': 1194,
#  'क्सों': 58,
#  'श्वा': 4478,
#  'र्वो': 1031,
#  'ब्रे': 1324,
#  'ब्लै': 528,
#  'स्टो': 1250,
#  'र्रा': 1256,
#  'र्डो': 152,
#  'चैं': 899,
#  'ट्रॉ': 277,
#  'ल्मी': 674,
#  'स्यी': 360,
#  'न्हे': 942,
#  'ट््': 54,
#  'न्मा': 321,
#  'फू': 3783,
#  'क्यु': 459,
#  'दां': 942,
#  'ड्री': 166,
#  'डे़': 316,
#  'र्यी': 42,
#  'र्वि': 1317,
#  'व्यं': 556,
#  'चीं': 224,
#  'त्तों': 470,
#  'स्कु': 842,
#  'टं': 510,
#  'ल्का': 493,
#  'न्नी': 849,
#  'ह्मे': 72,
#  'क्रो': 1679,
#  'त्थ': 1533,
#  'ख्ती': 242,
#  'श्न': 2612,
#  'र्थों': 523,
#  'ज्ञ': 1792,
#  'प्ति': 1244,
#  'ढे़': 63,
#  'ल्फें': 26,
#  'ड्र': 298,
#  'ग्स': 883,
#  'आॢ': 40,
#  'म्भा': 436,
#  'म्बो': 271,
#  'न्म': 3925,
#  'र्जि': 782,
#  'ह्म': 1512,
#  'गुं': 758,
#  'स्टॉ': 604,
#  'श्लो': 173,
#  'स्थी': 248,
#  'क्की': 1118,
#  'त्ये': 1332,
#  'बौ': 1019,
#  'ज्वे': 86,
#  'ती़': 2,
#  'घी': 670,
#  'ढां': 652,
#  'य्या': 360,
#  'ठौ': 257,
#  'व्वा': 158,
#  'यूं': 983,
#  'षे': 696,
#  'घे': 1326,
#  ...}

# %%
detectConsonants_Matra={}
def detectConsonantMatra(word):
    chars = list(word) 
#     print(f'chars:{chars}')
    a = ''
    enum_iter = enumerate(chars)
    flag = 0
    for index, char in enum_iter:
        a =''
        if(isConsonant(char)):
            a+=char
            i=0;
            while (index+1 < len(chars) and  isMatra(chars[index+1])):
                index, char = next(enum_iter)
                a += char
                i+=1
            if a in detectConsonants_Matra: 
                continue
            elif(i!=0): 
                detectConsonants_Matra.update({a: i})

# %%
for para in new_sample:
    words = para.split()
    for word in words:
        detectConsonantMatra(word)

# %%
detectConsonants_Matra
# Out:
# {'पू': 1,
#  'र्': 1,
#  'पा': 1,
#  'कि': 1,
#  'स्': 1,
#  'ता': 1,
#  'नी': 1,
#  'प्': 1,
#  'ने': 1,
#  'हा': 1,
#  'दि': 1,
#  'खि': 1,
#  'ला': 1,
#  'ड़ी': 1,
#  'बा': 1,
#  'भू': 1,
#  'ना': 1,
#  'भी': 1,
#  'चा': 1,
#  'हे': 1,
#  'तो': 1,
#  'क्': 1,
#  'रि': 1,
#  'के': 1,
#  'रे': 1,
#  'मी': 1,
#  'डि': 1,
#  'या': 1,
#  'सा': 1,
#  'हीं': 2,
#  'दे': 1,
#  'है': 1,
#  'न्': 1,
#  'हों': 2,
#  'लो': 1,
#  'ते': 1,
#  'हैं': 2,
#  'शे': 1,
#  'में': 2,
#  'हु': 1,
#  'हो': 1,
#  'ले': 1,
#  'भा': 1,
#  'मै': 1,
#  'चों': 2,
#  'जि': 1,
#  'सी': 1,
#  'खे': 1,
#  'च्': 1,
#  'छा': 1,
#  'मा': 1,
#  'फो': 1,
#  'लि': 1,
#  'टिं': 2,
#  'से': 1,
#  'मि': 1,
#  'जा': 1,
#  'गे': 1,
#  'मु': 1,
#  'ब्': 1,
#  'वा': 1,
#  'को': 1,
#  'गो': 1,
#  'घु': 1,
#  'रें': 2,
#  'वी': 1,
#  'कै': 1,
#  'सं': 1,
#  'त्': 1,
#  'ति': 1,
#  'लं': 1,
#  'बे': 1,
#  'ती': 1,
#  'का': 1,
#  'मौ': 1,
#  'जू': 1,
#  'दा': 1,
#  'जी': 1,
#  'शै': 1,
#  'ली': 1,
#  'झौ': 1,
#  'हि': 1,
#  'नि': 1,
#  'वे': 1,
#  'री': 1,
#  'कु': 1,
#  'की': 1,
#  'द्': 1,
#  'रा': 1,
#  'फी': 1,
#  'हं': 1,
#  'गा': 1,
#  'धि': 1,
#  'ही': 1,
#  'सृ': 1,
#  'था': 1,
#  'गी': 1,
#  'किं': 2,
#  'पॉ': 1,
#  'बें': 2,
#  'ढ़ी': 2,
#  'कें': 2,
#  'कं': 1,
#  'जे': 1,
#  'रो': 1,
#  'लिं': 2,
#  'खा': 1,
#  'सें': 2,
#  'सि': 1,
#  'लै': 1,
#  'फॉ': 1,
#  'शु': 1,
#  'रु': 1,
#  'शि': 1,
#  'रू': 1,
#  'ग्': 1,
#  'पु': 1,
#  'ड़ू': 2,
#  'पो': 1,
#  'ढ़': 1,
#  'शा': 1,
#  'मं': 1,
#  'बि': 1,
#  'बै': 1,
#  'म्': 1,
#  'ठा': 1,
#  'लां': 2,
#  'ल्': 1,
#  'लू': 1,
#  'डी': 1,
#  'घा': 1,
#  'सुं': 2,
#  'कां': 2,
#  'पि': 1,
#  'सो': 1,
#  'टी': 1,
#  'बं': 1,
#  'दी': 1,
#  'मां': 2,
#  'जु': 1,
#  'तृ': 1,
#  'ट्': 1,
#  'हुं': 2,
#  'चे': 1,
#  'थे': 1,
#  'फ्': 1,
#  'नों': 2,
#  'टि': 1,
#  'वै': 1,
#  'ठि': 1,
#  'यों': 2,
#  'ढा': 1,
#  'ढ़ा': 2,
#  'पी': 1,
#  'गों': 2,
#  'यी': 1,
#  'थी': 1,
#  'डूं': 2,
#  'नु': 1,
#  'फ़ी': 2,
#  'थि': 1,
#  'धा': 1,
#  'रं': 1,
#  'छो': 1,
#  'ड़': 1,
#  'श्': 1,
#  'गु': 1,
#  'दं': 1,
#  'ख्': 1,
#  'मो': 1,
#  'ड़े': 1,
#  'भं': 1,
#  'सु': 1,
#  'शी': 1,
#  'मे': 1,
#  'टे': 1,
#  'यु': 1,
#  'लॉ': 1,
#  'डें': 2,
#  'फा': 1,
#  'जॉ': 1,
#  'दू': 1,
#  'सौ': 1,
#  'झी': 1,
#  'यें': 2,
#  'ष्': 1,
#  'फै': 1,
#  'बी': 1,
#  'जां': 2,
#  'पां': 2,
#  'रों': 2,
#  'वि': 1,
#  'व्': 1,
#  'तै': 1,
#  'दो': 1,
#  'तं': 1,
#  'रौ': 1,
#  'यो': 1,
#  'गि': 1,
#  'तां': 2,
#  'ड़ा': 2,
#  'तौ': 1,
#  'जो': 1,
#  'लों': 2,
#  'शों': 2,
#  'ची': 1,
#  'कों': 2,
#  'वृ': 1,
#  'षा': 1,
#  'ड़ी': 2,
#  'ये': 1,
#  'यां': 2,
#  'यू': 1,
#  'मॉ': 1,
#  'जिं': 2,
#  'बां': 2,
#  'पिं': 2,
#  'षी': 1,
#  'तें': 2,
#  'खें': 2,
#  'ज्': 1,
#  'कू': 1,
#  'धी': 1,
#  'ध्': 1,
#  'दौ': 1,
#  'गिं': 2,
#  'खों': 2,
#  'बैं': 2,
#  'फि': 1,
#  'भो': 1,
#  'चु': 1,
#  'ढ़ा': 1,
#  'बो': 1,
#  'पे': 1,
#  'हें': 2,
#  'दु': 1,
#  'कॉ': 1,
#  'कैं': 2,
#  'तों': 2,
#  'थो': 1,
#  'णा': 1,
#  'झे': 1,
#  'मैं': 2,
#  'धों': 2,
#  'छी': 1,
#  'रॉ': 1,
#  'डे': 1,
#  'लौ': 1,
#  'टैं': 2,
#  'ठी': 1,
#  'टा': 1,
#  'पै': 1,
#  'सू': 1,
#  'नं': 1,
#  'डो': 1,
#  'नू': 1,
#  'गं': 1,
#  'रिं': 2,
#  'बू': 1,
#  'टू': 1,
#  'ड़ा': 1,
#  'भि': 1,
#  'जें': 2,
#  'गृ': 1,
#  'खु': 1,
#  'चि': 1,
#  'चं': 1,
#  'वों': 2,
#  'फें': 2,
#  'णे': 1,
#  'हां': 2,
#  'ढ़े': 2,
#  'शं': 1,
#  'कृ': 1,
#  'षि': 1,
#  'षे': 1,
#  'सिं': 2,
#  'गें': 2,
#  'शो': 1,
#  'णि': 1,
#  'थों': 2,
#  'छे': 1,
#  'णी': 1,
#  'हिं': 2,
#  'ड़ों': 2,
#  'मू': 1,
#  'खं': 1,
#  'जों': 2,
#  'चो': 1,
#  'भ्': 1,
#  'चू': 1,
#  'डा': 1,
#  'पं': 1,
#  'गां': 2,
#  'चौ': 1,
#  'तु': 1,
#  'नुु': 2,
#  'खो': 1,
#  'ऩे': 1,
#  'डि़': 2,
#  'घ्': 1,
#  'लें': 2,
#  'मिं': 2,
#  'निं': 2,
#  'मों': 2,
#  'विं': 2,
#  'भां': 2,
#  'लॉं': 2,
#  'चै': 1,
#  'छि': 1,
#  'ञा': 1,
#  'हौ': 1,
#  'फे': 1,
#  'थु': 1,
#  'ड़ि': 2,
#  'शू': 1,
#  'ञ्': 1,
#  'शिं': 2,
#  'नौ': 1,
#  'थीं': 2,
#  'झू': 1,
#  'ठे': 1,
#  'दों': 2,
#  'जै': 1,
#  'मृ': 1,
#  'डु': 1,
#  'वं': 1,
#  'रां': 2,
#  'र्ा': 2,
#  'लु': 1,
#  'बिं': 2,
#  'यं': 1,
#  'झा': 1,
#  'हू': 1,
#  'सां': 2,
#  'य्': 1,
#  'ष्ाी': 3,
#  'छू': 1,
#  'खी': 1,
#  'चां': 2,
#  'यि': 1,
#  'ड़ों': 3,
#  'ण्': 1,
#  'नीं': 2,
#  'गू': 1,
#  'ड़े': 2,
#  'डिं': 2,
#  'पों': 2,
#  'कौ': 1,
#  'हूं': 2,
#  'भे': 1,
#  'लैं': 2,
#  'पृ': 1,
#  'थ्': 1,
#  'रै': 1,
#  'बों': 2,
#  'डॉ': 1,
#  'भु': 1,
#  'डों': 2,
#  'ढ़ो': 2,
#  'वां': 2,
#  'चिं': 2,
#  'ढ़ी': 1,
#  'ठीं': 2,
#  'नैं': 2,
#  'सै': 1,
#  'धां': 2,
#  'षों': 2,
#  'ड़़ें': 4,
#  'बु': 1,
#  'दें': 2,
#  'घं': 1,
#  'टों': 2,
#  'धे': 1,
#  'ढ़ो': 1,
#  'ढु': 1,
#  'ठु': 1,
#  'ठं': 1,
#  'धू': 1,
#  'फ़ो': 2,
#  'शॉ': 1,
#  'टें': 2,
#  'गै': 1,
#  'गौ': 1,
#  'वो': 1,
#  'वीं': 2,
#  'रैं': 2,
#  'डू': 1,
#  'ढं': 1,
#  'नॉ': 1,
#  'मुं': 2,
#  'घो': 1,
#  'णों': 2,
#  'टो': 1,
#  'धं': 1,
#  'भुं': 2,
#  'धो': 1,
#  'वु': 1,
#  'यौ': 1,
#  'खू': 1,
#  'सैं': 2,
#  'जुं': 2,
#  'नै': 1,
#  'ड़ो': 1,
#  'ज़': 1,
#  'नें': 2,
#  'झो': 1,
#  'हॉ': 1,
#  'नो': 1,
#  'वें': 2,
#  'शां': 2,
#  'झं': 1,
#  'बॉ': 1,
#  'फ़ा': 2,
#  'फ़ें': 3,
#  'सौं': 2,
#  'घू': 1,
#  'धृ': 1,
#  'फ़ि': 2,
#  'ड्': 1,
#  'फैं': 2,
#  'फ़ु': 2,
#  'पें': 2,
#  'कुं': 2,
#  'ह्': 1,
#  'रीं': 2,
#  'खिं': 2,
#  'सों': 2,
#  'छूं': 2,
#  'पौ': 1,
#  'तू': 1,
#  'धु': 1,
#  'भौं': 2,
#  'झु': 1,
#  'भौ': 1,
#  'रृं': 2,
#  'दृ': 1,
#  'ज्ाि': 3,
#  'थॉ': 1,
#  'थै': 1,
#  'षु': 1,
#  'घि': 1,
#  'हृ': 1,
#  'चें': 2,
#  'बृ': 1,
#  'छु': 1,
#  'भै': 1,
#  'रूं': 2,
#  'दूं': 2,
#  'कीं': 2,
#  'वॉ': 1,
#  'ढी': 1,
#  'फु': 1,
#  'जं': 1,
#  'तीं': 2,
#  'टै': 1,
#  'शें': 2,
#  'बूं': 2,
#  'ब़': 1,
#  'डां': 2,
#  'ढे': 1,
#  'भें': 2,
#  'ड़ि': 1,
#  'ढ़ि': 1,
#  'खौ': 1,
#  'णु': 1,
#  'टं': 1,
#  'ऱ': 1,
#  'टौ': 1,
#  'चैं': 2,
#  'ट््': 2,
#  'फू': 1,
#  'दां': 2,
#  'डे़': 2,
#  'चीं': 2,
#  'ढे़': 2,
#  'गुं': 2,
#  'टॉ': 1,
#  'बौ': 1,
#  'ती़': 2,
#  'घी': 1,
#  'ढां': 2,
#  'ठौ': 1,
#  'यूं': 2,
#  'घे': 1,
#  'खीं': 2,
#  'चूं': 2,
#  'यीं': 2,
#  'ङो': 1,
#  'पूं': 2,
#  'ठों': 2,
#  'छं': 1,
#  'फं': 1,
#  'दै': 1,
#  'चुं': 2,
#  'कॅ': 1,
#  'फ़': 1,
#  'ठो': 1,
#  'खै': 1,
#  'शौं': 2,
#  'जीं': 2,
#  'षो': 1,
#  'नः': 1,
#  'यॉ': 1,
#  'झां': 2,
#  'वा़': 2,
#  'फां': 2,
#  'ख़': 1,
#  'फै्': 2,
#  'फूं': 2,
#  'ढ़े': 1,
#  'शृं': 2,
#  'टु': 1,
#  'ड़ू': 1,
#  'शौ': 1,
#  'हींं': 3,
#  'ड़ें': 2,
#  'मीं': 2,
#  'घों': 2,
#  'मौै': 2,
#  'ढि': 1,
#  'मेंे': 3,
#  'सॉ': 1,
#  'पौं': 2,
#  'डै': 1,
#  'चॉ': 1,
#  'ढ़्': 2,
#  'वू': 1,
#  'लीं': 2,
#  'जैं': 2,
#  'ताॢ': 2,
#  'ढ़ें': 3,
#  'धौ': 1,
#  'थू': 1,
#  'फ़ै': 2,
#  'जौ': 1,
#  'झें': 2,
#  'फौ': 1,
#  'धाॢ': 2,
#  'पाॢ': 2,
#  'नॢ': 1,
#  'सीं': 2,
#  'खां': 2,
#  'नृ': 1,
#  'ढो': 1,
#  'घृ': 1,
#  'बुं': 2,
#  'खूं': 2,
#  'रः': 1,
#  'धुं': 2,
#  'हंीं': 3,
#  'ज़्': 2,
#  'हूँ': 2,
#  'घौ': 1,
#  'गैं': 2,
#  'याः': 2,
#  'ढूं': 2,
#  'हंु': 2,
#  'ड़ें': 3,
#  'ड़ौ': 2,
#  'होें': 3,
#  'न््': 2,
#  'रोे': 2,
#  'गूं': 2,
#  'पैं': 2,
#  'य़ों': 2,
#  'झों': 2,
#  'ठू': 1,
#  'मंे': 2,
#  'यिं': 2,
#  'नौं': 2,
#  'ष्ाों': 4,
#  'हाें': 3,
#  'हंी': 2,
#  'ठूं': 2,
#  'क़': 1,
#  'गु्': 2,
#  'के़': 2,
#  'चौं': 2,
#  'मूं': 2,
#  'हंै': 2,
#  'ड़ो': 2,
#  'ढें': 2,
#  'डि्': 2,
#  'ठ्': 1,
#  'दिा': 2,
#  'तिा': 2,
#  'षां': 2,
#  'टे्': 2,
#  'मुंं': 3,
#  'ष्ा': 2,
#  'द््': 2,
#  'क्ि': 2,
#  'ङ्': 1,
#  'सूं': 2,
#  'झि': 1,
#  'नेे': 2,
#  'कौं': 2,
#  'भैं': 2,
#  'ऩे': 2,
#  'वॢ': 1,
#  'णो': 1,
#  'ढ़ि': 2,
#  'क््': 2,
#  'फ़े': 2,
#  'ढ़ौ': 2,
#  'ऩा': 1,
#  'टां': 2,
#  'डं': 1,
#  'ज़ा': 2,
#  'डॅा': 2,
#  'ढिं': 2,
#  'य़ों': 3,
#  'तूं': 2,
#  'गॉ': 1,
#  'लीः': 2,
#  'नां': 2,
#  'हौं': 2,
#  'ञों': 2,
#  'धै': 1,
#  'यै': 1,
#  'पीं': 2,
#  'युं': 2,
#  'य़ू': 2,
#  'योंे': 3,
#  'ग़ां': 2,
#  'ढ़ं': 2,
#  'ढ़ों': 3,
#  'फ़ं': 2,
#  'भिं': 2,
#  'ढ्': 1,
#  'पुं': 2,
#  'ठें': 2,
#  'ख़ा': 1,
#  'माँ': 2,
#  'टुं': 2,
#  'घूं': 2,
#  'छुं': 2,
#  'हेा': 2,
#  'ड़ं': 2,
#  'फ़ॉ': 2,
#  'लौं': 2,
#  'कोें': 3,
#  'रौं': 2,
#  'थिं': 2,
#  'ढों': 2,
#  'हैंं': 3,
#  'ड़ु': 1,
#  'लूं': 2,
#  'हुँ': 2,
#  'दंे': 2,
#  'मेैं': 3,
#  'टीं': 2,
#  'चीः': 2,
#  'रि्': 2,
#  'गीं': 2,
#  'ताी': 2,
#  'ठिं': 2,
#  'ञे': 1,
#  'छां': 2,
#  'काा': 2,
#  'छौ': 1,
#  'है़': 2,
#  'रुं': 2,
#  'दॢ': 1,
#  'दीं': 2,
#  'तः': 1,
#  'झुं': 2,
#  'ज़े': 2,
#  'थैं': 2,
#  'सॉं': 2,
#  'यूू': 2,
#  'संा': 2,
#  'ड़ीं': 3,
#  'दुः': 2,
#  'नूं': 2,
#  'शैं': 2,
#  'वांे': 3,
#  'यांे': 3,
#  'धु्': 2,
#  'कााेंं': 5,
#  'खंू': 2,
#  'भों': 2,
#  'डुं': 2,
#  'शः': 1,
#  'य़ा': 1,
#  'कें्': 3,
#  'माे': 2,
#  'कांे': 3,
#  'फिं': 2,
#  'छ्': 1,
#  'नाें': 3,
#  'हुुं': 3,
#  'ज़ी': 2,
#  'ढि़': 2,
#  'क़ी': 2,
#  'टः': 1,
#  'फें्': 3,
#  'कंा': 2,
#  'य़ां': 2,
#  'हैः': 2,
#  'टै्': 2,
#  'ज़ि': 2,
#  'श्ुा': 3,
#  'घां': 2,
#  'हैे': 2,
#  'फ़ों': 3,
#  'फॉं': 2,
#  'चै़': 2,
#  'ज़ें': 2,
#  'फों': 2,
#  'झिं': 2,
#  'मेें': 3,
#  'हंू': 2,
#  'ढै': 1,
#  'हेे': 2,
#  'फ़ां': 3,
#  'ऱों': 2,
#  'बेंे': 3,
#  'मेंं': 3,
#  'हांे': 3,
#  'लः': 1,
#  'फ़ू': 2,
#  'छें': 2,
#  'डंै': 2,
#  'चंू': 2,
#  'डौ': 1,
#  'धें': 2,
#  'णं': 1,
#  'केे': 2,
#  'शि्': 2,
#  'रांे': 3,
#  'फुं': 2,
#  'पी़': 2,
#  'रीः': 2,
#  'षै': 1,
#  'र्ें': 3,
#  'पै्': 2,
#  'कूं': 2,
#  'तिं': 2,
#  'योे': 2,
#  'चाः': 2,
#  'सिा': 2,
#  'ड़ीं': 2,
#  'धौं': 2,
#  'ढू': 1,
#  'जूं': 2,
#  'थें': 2,
#  'ड़़': 2,
#  'थौ': 1,
#  'भिा': 2,
#  'बे्': 2,
#  'द्ों': 3,
#  'भीं': 2,
#  'ढ़ीं': 3,
#  'टाें': 3,
#  'सेें': 3,
#  'झ्': 1,
#  'टि्': 2,
#  'बः': 1,
#  'लंे': 2,
#  'लांे': 3,
#  'मः': 1,
#  'गांे': 3,
#  'पाँ': 2,
#  'काू': 2,
#  'ख़ि': 2,
#  'ढीं': 2,
#  'भू्': 2,
#  'हंूं': 3,
#  'ग़ु': 2,
#  'यंू': 2,
#  'थ्ौ': 2,
#  'मोऽ': 2,
#  'यः': 1,
#  'दुं': 2,
#  'ङों': 2,
#  'छौं': 2,
#  'तिी': 2,
#  'हाँ': 2,
#  'यूँ': 2,
#  'छीं': 2,
#  'रृ': 1,
#  'थां': 2,
#  'बंै': 2,
#  'दौै': 2,
#  'ज़ा': 1,
#  'ऱां': 2,
#  'ख़ु': 2,
#  'धाा': 2,
#  'धीं': 2,
#  'कः': 1,
#  'ज़ें': 3,
#  'थ्ीा': 3,
#  'शाें': 3,
#  'रेे': 2,
#  'ताा': 2,
#  'टौं': 2,
#  'टंें': 3,
#  'हंे': 2,
#  'ना्': 2,
#  'बीं': 2,
#  'ध़े': 2,
#  'जौं': 2,
#  'ढ़ें': 2,
#  'फ़ौ': 2,
#  'थं': 1,
#  'येा': 2,
#  'नाः': 2,
#  'वाू': 2,
#  'च्ं': 2,
#  'गं्': 2,
#  'शॄ': 1,
#  'के्': 2,
#  'विे': 2,
#  'षं': 1,
#  'दः': 1,
#  'ज़िं': 3,
#  'ढ़ां': 3,
#  'माें': 3,
#  'गंा': 2,
#  'श्ृं': 3,
#  'दिं': 2,
#  'ठंू': 2,
#  'श्े': 2,
#  'ठै': 1,
#  'पॢ': 1,
#  'ति़': 2,
#  'फि़': 2,
#  'ढ़ू': 2,
#  'क़ा': 2,
#  'याें': 3,
#  'मु्': 2,
#  'धिं': 2,
#  'रेः': 2,
#  'निः': 2,
#  'ग़': 1,
#  'जि़': 2,
#  'वृं': 2,
#  'साें': 3,
#  'झौं': 2,
#  'खुं': 2,
#  'ड़ं': 1,
#  'ख़ु': 1,
#  'मेे': 2,
#  'तोें': 3,
#  'होंं': 3,
#  'च्ें': 3,
#  'छुंि': 3,
#  'मंै': 2,
#  'छृं': 2,
#  'शाु': 2,
#  'ऩ': 1,
#  'ड््': 2,
#  'यिा': 2,
#  'ड़ूं': 2,
#  'डा़': 2,
#  'दाा': 2,
#  'ख़ू': 2,
#  'टूं': 2,
#  'मंं': 2,
#  'तैं': 2,
#  'सॢ': 1,
#  'विा': 2,
#  'ड़ौ': 1,
#  'ड्ं': 2,
#  'यंा': 2,
#  'याँ': 2,
#  'ज़ि': 1,
#  'फ्ी': 2,
#  'माॢ': 2,
#  'ब्ा': 2,
#  'बुु': 2,
#  'मंौ': 2,
#  'सः': 1,
#  'णें': 2,
#  'डेे': 2,
#  'य़े': 1,
#  'ज़ॉ': 2,
#  'फ़ि': 1,
#  'कंु': 2,
#  'कोे': 2,
#  'होे': 2,
#  'चं्': 2,
#  'मंा': 2,
#  'गेे': 2,
#  'गे्': 2,
#  'ढ़ै': 2,
#  'च़ु': 2,
#  'य़े': 2,
#  'शुाि': 3,
#  'लि्': 2,
#  'ज़ू': 2,
#  'ज़ो': 2,
#  'योें': 3,
#  'देें': 3,
#  'वोिं': 3,
#  'राेंं': 4,
#  'श़': 1,
#  'हूंं': 3,
#  'बँ': 1,
#  'मंें': 3,
#  'बु्': 2,
#  'य़': 1,
#  'नोे': 2,
#  'हॢ': 1,
#  'जाॢ': 2,
#  'घें': 2,
#  'ढौं': 2,
#  'णौ': 1,
#  'बौं': 2,
#  'ठां': 2,
#  'स््': 2,
#  'सेे': 2,
#  'कंं': 2,
#  'गोें': 3,
#  'ज़ु': 2,
#  'गुु': 2,
#  'भृ': 1,
#  'राें': 3,
#  'नांे': 3,
#  'लेा': 2,
#  'ऩा': 2,
#  'ताें': 3,
#  'शोें': 3,
#  'ढ़ों': 2,
#  'फ़्': 2,
#  'या़': 2,
#  'ची़': 2,
#  'य़ा': 2,
#  'नोंे': 3,
#  'तांे': 3,
#  'सोॄ': 2,
#  'ड़ॉ': 2,
#  'णीं': 2,
#  'ब्ा्': 3,
#  'मांं': 3,
#  'तुं': 2,
#  'येां': 3,
#  'स्ा': 2,
#  'तेऽ': 2,
#  'डः': 1,
#  'वैं': 2,
#  'धाी': 2,
#  'दं्': 2,
#  'भूं': 2,
#  'रेा': 2,
#  'टेे': 2,
#  'चोे': 2,
#  'ऩी': 2,
#  'हैंंं': 4,
#  'डी़': 2,
#  'सी़': 2,
#  'ज़ी': 1,
#  'फैं्': 3,
#  'र्ाा': 3,
#  'लाः': 2,
#  'ज़ो': 1,
#  'गाँ': 2,
#  'डैं': 2,
#  'झीं': 2,
#  'कू्': 2,
#  'गौं': 2,
#  'ठ््': 2,
#  'फ़ो': 1,
#  'यू्': 2,
#  'र्ं': 2,
#  'नाी': 2,
#  'गंू': 2,
#  'लुं': 2,
#  'ट्े': 2,
#  'शूंि': 3,
#  'य़ू': 1,
#  'गाः': 2,
#  'रूू': 2,
#  'र्ू': 2,
#  'जोे': 2,
#  'संं': 2,
#  'णू': 1,
#  'ड़ै': 2,
#  'डे्': 2,
#  'ड़ु': 2,
#  'स्े': 2,
#  'रेै': 2,
#  'ल्ं': 2,
#  'योंं': 3,
#  'नाेंं': 4,
#  'कॢ': 1,
#  'च्े': 2,
#  'थूं': 2,
#  'गाें': 3,
#  'ज़े': 1,
#  'छै': 1,
#  'धिा': 2,
#  'हँ': 1,
#  'धिः': 2,
#  'ख़ि': 1,
#  'यौं': 2,
#  'य़ो': 2,
#  'बॄ': 1,
#  ...}

# %%
df1=pd.DataFrame.from_dict(dictionary_vowel, orient='index',columns=[ 'Frequency'])
print(df1.index)


ind=[]
ind=list(df1.index)
indi = [ 'u' + f"'\\u" + f"{str(ord(x))}'" for x in list(df1.index)]
# Out:
# Index(['अ', 'औ', 'ऐ', 'उ', 'ए', 'इ', 'आ', 'ई', 'ऊ', 'ओ', 'ऑ', 'ऋ', 'ऎ', 'ॠ',
#        'ऍ', 'ऌ', 'ऒ'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager as fm, rcParams
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
sns.set(font="Meiryo")

# %%
df1.to_csv('vowel_freq.csv')

# %%
Data1 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/vowel_freq.csv")

# %%
Data1.index
Data1
# Out:
#    Unnamed: 0  Frequency
# 0           अ     429904
# 1           औ     205808
# 2           ऐ      34538
# 3           उ     304315
# 4           ए     410350
# 5           इ     294766
# 6           आ     337944
# 7           ई     187285
# 8           ऊ      14706
# 9           ओ      62414
# 10          ऑ      10063
# 11          ऋ       2121
# 12          ऎ        822
# 13          ॠ         38
# 14          ऍ        157
# 15          ऌ          3
# 16          ऒ          9

# %%
sns.barplot(y='Frequency',x=Data1.index,data=Data1.iloc[0:750,:])

# %%
df2=pd.DataFrame.from_dict(dictionary_consonant, orient='index',columns=[ 'Frequency'])
print(df2.index)
df2.to_csv('consonant_freq.csv',index = True)
Data2 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/consonant_freq.csv")
Data2
# Out:
# Index(['प', 'र', 'व', 'क', 'स', 'त', 'न', 'म', 'ह', 'य', 'द', 'ख', 'ल', 'ड़',
#        'ब', 'भ', 'च', 'श', 'ट', 'ड', 'ग', 'ज', 'थ', 'छ', 'फ', 'घ', 'झ', 'ध',
#        'ढ', 'ण', 'ठ', 'ष', 'ढ़', 'ऩ', 'ञ', 'ङ', 'य़', 'ळ', 'क़', 'ग़', 'ख़', 'ज़',
#        'ऱ', 'फ़'],
#       dtype='object')
#    Consonants  Frequency
# 0           प    1254359
# 1           र    3336110
# 2           व     973866
# 3           क    3623226
# 4           स    2110400
# 5           त    1768862
# 6           न    2238889
# 7           म    1736874
# 8           ह    2146189
# 9           य    1207779
# 10          द    1006684
# 11          ख     312081
# 12          ल    1425704
# 13          ड़      43471
# 14          ब     899384
# 15          भ     419506
# 16          च     454628
# 17          श     448619
# 18          ट     436552
# 19          ड     310843
# 20          ग     787541
# 21          ज     925475
# 22          थ     332103
# 23          छ     127886
# 24          फ     215071
# 25          घ      70504
# 26          झ      58741
# 27          ध     245538
# 28          ढ      48425
# 29          ण     129405
# 30          ठ      78913
# 31          ष     196826
# 32          ढ़       6863
# 33          ऩ       1073
# 34          ञ      13551
# 35          ङ       1195
# 36          य़        503
# 37          ळ        121
# 38          क़       1502
# 39          ग़        560
# 40          ख़        877
# 41          ज़       6391
# 42          ऱ        236
# 43          फ़       4604

# %%
sns.set(font="Meiryo",font_scale=0.5)
sns.barplot(y='Frequency',x=Data2.index,data=Data2.iloc[0:1500,:])

# %%
df3=pd.DataFrame.from_dict(words_with_half_consonant_following_vowel, orient='index',columns=[ 'Frequency'])
print(df3.index)
df3=df3.sort_values(by=['Frequency'],ascending=False)
df3.to_csv('half_cononant_vowel.csv',index = True)
# Out:
# Index(['मेंच्अच्छा', 'डिस्ऑर्डर', 'हुर्ई।', 'च्ए', 'गर्इं।', 'हुर्इं',
#        'र्इंट,', '‘र्इंटें’,', 'कार्रवार्ई', 'प्रतिच्अच्छी',
#        ...
#        'रेलवे-लार्इन', 'स्थार्इ', 'एफडीआर्इ', 'कलार्इ', 'सद्उपदेश,', 'र्इंटें',
#        'बिलसपुरहिन-’’अइसर्इ', 'जबरर्इ', 'गर्इ?', 'सफार्इ'],
#       dtype='object', length=212)

# %%
Data3 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/half_cononant_vowel.csv")
Data3=Data3[0:20]
Data3
# Out:
#         Words  Frequency
# 0       कोर्इ         42
# 1        गर्इ         26
# 2   डिस्ऑर्डर         23
# 3       गर्इ।         22
# 4      गर्इं।         21
# 5       हुर्इ         20
# 6        कर्इ         13
# 7       गर्इं          8
# 8      हुर्इ।          8
# 9     दिखार्इ          8
# 10       आर्इ          7
# 11     गर्इं,          7
# 12      आर्इ।          6
# 13        च्ए          5
# 14    हुर्इं।          5
# 15      गर्ई।          5
# 16     र्इंधन          4
# 17    हुर्इं,          4
# 18     हुर्इं          4
# 19  एप्एमसीजी          3

# %%
sns.set(font="Meiryo",font_scale=0.9)
sns.barplot(y='Frequency',x=Data3.index,data=Data3.iloc[0:1500,:])

# %%
df4=pd.DataFrame.from_dict(words_with_half_consonant_following_matra, orient='index',columns=[ 'Frequency'])
print(df4.index)
df4=df4.sort_values(by=['Frequency'],ascending=False)
df4.to_csv('half_cononant_matra.csv',index = True)
# Out:
# Index(['जलर्ापूत्ति', 'वष्ाीüय', 'सुसज्ज्ाित', 'मुट््ठीभर', 'केन््रद',
#        'पुरूष्ाों', 'पाष्ाüद', 'मुद््दों', 'क्िलंटन', 'कट््टे',
#        ...
#        'छ्ःओटी', 'प्रा्रोत्ेत्साहित', 'पालन-पोष्ाण', '(ब्ा्रह्म)', 'विध्ेयक',
#        'कलारूप्ा', 'मैंट्ो', 'राष्ट्र्ीय', 'एफटर््स', 'ज़्पारोशिया'],
#       dtype='object', length=476)

# %%
Data4 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/half_cononant_matra.csv")
Data4=Data4[0:20]
Data4
# Out:
#               Words  Frequency
# 0             वष्ाü         20
# 1          निदर्ेशक         20
# 2           परिष्ाद         14
# 3             वक़्त         14
# 4           मिट््टी         13
# 5            कृçष्ा         11
# 6           वष्ाीüय         11
# 7       जलर्ापूत्ति         10
# 8           मुद््दा         10
# 9   कार्यकत्तर्ााओं         10
# 10       निदर्ेशकों         10
# 11          विशेष्ा         10
# 12          केन््रद          9
# 13         मुद््दों          9
# 14          मुद््दे          8
# 15            शेष्ा          8
# 16         उच्च्ंची          7
# 17          घोष्ाणा          7
# 18        उद््देश्य          7
# 19           विष्ाय          7

# %%
sns.set(font="Meiryo",font_scale=0.9)
sns.barplot(y='Frequency',x=Data4.index,data=Data4.iloc[0:1500,:])

# %%
df5=pd.DataFrame.from_dict(detectChars, orient='index',columns=[ 'Frequency'])
print(df5.index)
df5=df5.sort_values(by=['Frequency'],ascending=False)
# df5.to_csv('detectChars.csv',index = True)
Data5 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/detectChars.csv")
Data5=Data5[0:20]
Data5
# Out:
# Index(['का', 'पू', 'र्व', 'पा', 'कि', 'स्ता', 'नी', 'क', 'प्ता', 'न',
#        ...
#        'ट्.', 'दे्व', 'निंं', 'र्पः', 'ठ्या', 'ह्लो', 'च्चोे', 'त्न्', 'त्साा',
#        'ड़्ड'],
#       dtype='object', length=8491)
#    Characters  Frequency
# 0           र    1678224
# 1           क    1004802
# 2           न     861356
# 3           स     817892
# 4           प     632892
# 5          के     607038
# 6           ह     536967
# 7          ने     525971
# 8           ल     523101
# 9           त     516523
# 10          म     490531
# 11         का     480299
# 12          ब     431980
# 13        में     410243
# 14         है     403619
# 15          अ     398585
# 16         की     393149
# 17          ए     385961
# 18          ग     373410
# 19         से     368859

# %%
sns.set(font="Meiryo",font_scale=0.9)
sns.barplot(y='Frequency',x=Data5.index,data=Data5.iloc[0:1500,:])

# %%
df6=pd.DataFrame.from_dict(detectConsonants_Matra, orient='index',columns=[ 'Frequency'])
print(df6.index)
df6=df6.sort_values(by=['Frequency'],ascending=False)
# df6.to_csv('detectConsonants_Matra.csv',index = True)
Data6 = pd.read_csv(r"/Users/shivanitripathi/Documents/study material/DS/OLAM/datagen/detectConsonants_Matra.csv")
Data6=Data6[0:20]
Data6
# Out:
# Index(['पू', 'र्', 'पा', 'कि', 'स्', 'ता', 'नी', 'प्', 'ने', 'हा',
#        ...
#        'झाा', 'पँू', 'विँ', 'ठिि', 'बंे', 'हाँं', 'नुे', 'किृ', 'ळौ', 'निंं'],
#       dtype='object', length=2957)
#    Characters  Frequency
# 0    मेंंंंंं          7
# 1     छेेेेेे          6
# 2      कोेेेे          5
# 3      कााेंं          5
# 4       खेेंं          4
# 5       यांें          4
# 6       ड़ी़ी          4
# 7       ज़्ाु          4
# 8       टेेंं          4
# 9       ग़्ाू          4
# 10      राेंं          4
# 11      हैंैं          4
# 12      रांंि          4
# 13      ख्ंिा          4
# 14      ष्ाों          4
# 15      ज़्ाू          4
# 16      र््िा          4
# 17      ड़़ें          4
# 18      ड़ांे          4
# 19      ड़ोंं          4

# %%
sns.set(font="Meiryo",font_scale=0.9)
sns.barplot(y='Frequency',x=Data6.index,data=Data6.iloc[0:1500,:])

# %%
encoder_dict= {
    "ऀ":"0",
    "ँ":"1",
    "ं":"2",
    "ः":"3",
    "ऄ":"4",
    "अ":"5",
    "आ":"6",
    "इ":"7",
    "ई":"8",
    "उ":"9",
    "ऊ":"10",
    "ऋ":"11",
    "ऌ":"12",
    "ऍ":"13",
    "ऎ":"14",
    "ए":"15",
    "ऐ":"16",
    "ऑ":"17",
    "ऒ":"18",
    "ओ":"19",
    "औ":"20",
    "क":"21",
    "ख":"22",
    "ग":"23",
    "घ":"24",
    "ङ":"25",
    "च":"26",
    "छ":"27",
    "ज":"28",
    "झ":"29",
    "ञ":"30",
    "ट":"31",
    "ठ":"32",
    "ड":"33",
    "ढ":"34",
    "ण":"35",
    "त":"36",
    "थ":"37",
    "द":"38",
    "ध":"39",
    "न":"40",
    "ऩ":"41",
    "प":"42",
    "फ":"43",
    "ब":"44",
    "भ":"45",
    "म":"46",
    "य":"47",
    "र":"48",
    "ऱ":"49",
    "ल":"50",
    "ळ":"51",
    "ऴ":"52",
    "व":"53",
    "श":"54",
    "ष":"55",
    "स":"56",
    "ा":"57",
    "ि":"58",
    "ी":"59",
    "ु":"60",
    "ू":"61",
    "ृ":"62",
    "ॄ":"63",
    "ॆ":"64",
    "े":"65",
    "ै":"66",
    "ॉ":"67",
    "ॊ":"68",
    "ो":"69",
    "ौ":"70",
    "्":"71",
    "ॎ":"72",
    "ॐ":"73",
    "ॏ":"74",
    "।":"75",
    "॥":"76",
    "०":"77",
    "१":"78",
    "२":"79",
    "३":"80",
    "४":"81",
    "५":"82",
    "६":"83",
    "७":"84",
    "८":"85",
    "९":"86",
    "ॕ":"87",
    "ॖ":"88",
    "ॗ":"89",
    "॰":"90",
    "ॱ":"91",
    "ॲ":"92",
    "ॳ":"93",
    "ॴ":"94",
    "ॵ":"95",
    "ॶ":"96",
    "ॷ":"97",
    "ॸ":"98",
    "ॹ":"99",
    "ॺ":"100",
    "ॻ":"101",
    "ॼ":"102",
    "ॽ":"103",
    "ॾ":"104",
    "ॿ":"105",
    "क़":"106",
    "ख़":"107",
    "ग़":"108",
    "ज़":"109",
    "ड़":"110",
    "ढ़":"111",
    "फ़":"112",
    "य़":"113",
    "ॠ":"114",
    "ॡ":"115",
    "ॢ":"116",
    "ॣ":"117"
}

# %%
from textGenerator import TextGenerator
# textGen = TextGenerator(filePath=os.path.join('hindiTexts.csv'))
textGen = TextGenerator()
data = textGen.data['text']
print(data[0])
# Out:
# पूर्व पाकिस्तानी कप्तान अकरम ने कहा कि यदि खिलाड़ी दबाव भूलना भी चाहे तो दर्शक, क्रिकेट प्रेमी और मीडिया ऐसा नहीं करने देता है। उन्होंने कहा, ‘‘ लोग कहते हैं कि एशेज में बहुत दबाव होता है लेकिन भारत पाकिस्तान के मैचों में जितना दबाव होता उतना किसी अन्य के साथ खेलने में नहीं होता है। हर खिलाड़ी इन मैचों में अच्छा प्रदर्शन करना चाहता है। ’’

# %%
chr(97)
# Out:
# 'a'

# %%
encoder_dict
# Out:
# {'ऀ': '0',
#  'ँ': '1',
#  'ं': '2',
#  'ः': '3',
#  'ऄ': '4',
#  'अ': '5',
#  'आ': '6',
#  'इ': '7',
#  'ई': '8',
#  'उ': '9',
#  'ऊ': '10',
#  'ऋ': '11',
#  'ऌ': '12',
#  'ऍ': '13',
#  'ऎ': '14',
#  'ए': '15',
#  'ऐ': '16',
#  'ऑ': '17',
#  'ऒ': '18',
#  'ओ': '19',
#  'औ': '20',
#  'क': '21',
#  'ख': '22',
#  'ग': '23',
#  'घ': '24',
#  'ङ': '25',
#  'च': '26',
#  'छ': '27',
#  'ज': '28',
#  'झ': '29',
#  'ञ': '30',
#  'ट': '31',
#  'ठ': '32',
#  'ड': '33',
#  'ढ': '34',
#  'ण': '35',
#  'त': '36',
#  'थ': '37',
#  'द': '38',
#  'ध': '39',
#  'न': '40',
#  'ऩ': '41',
#  'प': '42',
#  'फ': '43',
#  'ब': '44',
#  'भ': '45',
#  'म': '46',
#  'य': '47',
#  'र': '48',
#  'ऱ': '49',
#  'ल': '50',
#  'ळ': '51',
#  'ऴ': '52',
#  'व': '53',
#  'श': '54',
#  'ष': '55',
#  'स': '56',
#  'ा': '57',
#  'ि': '58',
#  'ी': '59',
#  'ु': '60',
#  'ू': '61',
#  'ृ': '62',
#  'ॄ': '63',
#  'ॆ': '64',
#  'े': '65',
#  'ै': '66',
#  'ॉ': '67',
#  'ॊ': '68',
#  'ो': '69',
#  'ौ': '70',
#  '्': '71',
#  'ॎ': '72',
#  'ॐ': '73',
#  'ॏ': '74',
#  '।': '75',
#  '॥': '76',
#  '०': '77',
#  '१': '78',
#  '२': '79',
#  '३': '80',
#  '४': '81',
#  '५': '82',
#  '६': '83',
#  '७': '84',
#  '८': '85',
#  '९': '86',
#  'ॕ': '87',
#  'ॖ': '88',
#  'ॗ': '89',
#  '॰': '90',
#  'ॱ': '91',
#  'ॲ': '92',
#  'ॳ': '93',
#  'ॴ': '94',
#  'ॵ': '95',
#  'ॶ': '96',
#  'ॷ': '97',
#  'ॸ': '98',
#  'ॹ': '99',
#  'ॺ': '100',
#  'ॻ': '101',
#  'ॼ': '102',
#  'ॽ': '103',
#  'ॾ': '104',
#  'ॿ': '105',
#  'क़': '106',
#  'ख़': '107',
#  'ग़': '108',
#  'ज़': '109',
#  'ड़': '110',
#  'ढ़': '111',
#  'फ़': '112',
#  'य़': '113',
#  'ॠ': '114',
#  'ॡ': '115',
#  'ॢ': '116',
#  'ॣ': '117',
#  '0': 118,
#  '1': 119,
#  '2': 120,
#  '3': 121,
#  '4': 122,
#  '5': 123,
#  '6': 124,
#  '7': 125,
#  '8': 126,
#  '9': 127,
#  'a': 128,
#  'b': 129,
#  'c': 130,
#  'd': 131,
#  'e': 132,
#  'f': 133,
#  'g': 134,
#  'h': 135,
#  'i': 136,
#  'j': 137,
#  'k': 138,
#  'l': 139,
#  'm': 140,
#  'n': 141,
#  'o': 142,
#  'p': 143,
#  'q': 144,
#  'r': 145,
#  's': 146,
#  't': 147,
#  'u': 148,
#  'v': 149,
#  'w': 150,
#  'x': 151,
#  'y': 152,
#  'z': 153,
#  'A': 128,
#  'B': 129,
#  'C': 130,
#  'D': 131,
#  'E': 132,
#  'F': 133,
#  'G': 134,
#  'H': 135,
#  'I': 136,
#  'J': 137,
#  'K': 138,
#  'L': 139,
#  'M': 140,
#  'N': 141,
#  'O': 142,
#  'P': 143,
#  'Q': 144,
#  'R': 145,
#  'S': 146,
#  'T': 147,
#  'U': 148,
#  'V': 149,
#  'W': 150,
#  'X': 151,
#  'Y': 152,
#  'Z': 153}

# %%
k = 118
for i in range (ord('0'), ord('9')+1):
    print(i, chr(i))
    encoder_dict[chr(i)] = k
    k = k+1
# Out:
# 48 0
# 49 1
# 50 2
# 51 3
# 52 4
# 53 5
# 54 6
# 55 7
# 56 8
# 57 9

# %%
k = 128 
for i in range (ord('A'), ord('Z')+1):
    print(i, chr(i))
    encoder_dict[chr(i)] = k
    k = k+1
# Out:
# 65 A
# 66 B
# 67 C
# 68 D
# 69 E
# 70 F
# 71 G
# 72 H
# 73 I
# 74 J
# 75 K
# 76 L
# 77 M
# 78 N
# 79 O
# 80 P
# 81 Q
# 82 R
# 83 S
# 84 T
# 85 U
# 86 V
# 87 W
# 88 X
# 89 Y
# 90 Z

# %%
chr(ord('z') - ord('a') + ord('A'))
# Out:
# 'Z'

# %%
import json

# %%
with open('characterClasses.json', 'w') as fp:
    json.dump(encoder_dict, fp)

# %%
characters = list(encoder_dict.keys())[:154]
classesCharacter = {} 
for i in range(0,154):
    classesCharacter[i] = characters[i]

print(classesCharacter)
# Out:
# {0: 'ऀ', 1: 'ँ', 2: 'ं', 3: 'ः', 4: 'ऄ', 5: 'अ', 6: 'आ', 7: 'इ', 8: 'ई', 9: 'उ', 10: 'ऊ', 11: 'ऋ', 12: 'ऌ', 13: 'ऍ', 14: 'ऎ', 15: 'ए', 16: 'ऐ', 17: 'ऑ', 18: 'ऒ', 19: 'ओ', 20: 'औ', 21: 'क', 22: 'ख', 23: 'ग', 24: 'घ', 25: 'ङ', 26: 'च', 27: 'छ', 28: 'ज', 29: 'झ', 30: 'ञ', 31: 'ट', 32: 'ठ', 33: 'ड', 34: 'ढ', 35: 'ण', 36: 'त', 37: 'थ', 38: 'द', 39: 'ध', 40: 'न', 41: 'ऩ', 42: 'प', 43: 'फ', 44: 'ब', 45: 'भ', 46: 'म', 47: 'य', 48: 'र', 49: 'ऱ', 50: 'ल', 51: 'ळ', 52: 'ऴ', 53: 'व', 54: 'श', 55: 'ष', 56: 'स', 57: 'ा', 58: 'ि', 59: 'ी', 60: 'ु', 61: 'ू', 62: 'ृ', 63: 'ॄ', 64: 'ॆ', 65: 'े', 66: 'ै', 67: 'ॉ', 68: 'ॊ', 69: 'ो', 70: 'ौ', 71: '्', 72: 'ॎ', 73: 'ॐ', 74: 'ॏ', 75: '।', 76: '॥', 77: '०', 78: '१', 79: '२', 80: '३', 81: '४', 82: '५', 83: '६', 84: '७', 85: '८', 86: '९', 87: 'ॕ', 88: 'ॖ', 89: 'ॗ', 90: '॰', 91: 'ॱ', 92: 'ॲ', 93: 'ॳ', 94: 'ॴ', 95: 'ॵ', 96: 'ॶ', 97: 'ॷ', 98: 'ॸ', 99: 'ॹ', 100: 'ॺ', 101: 'ॻ', 102: 'ॼ', 103: 'ॽ', 104: 'ॾ', 105: 'ॿ', 106: 'क़', 107: 'ख़', 108: 'ग़', 109: 'ज़', 110: 'ड़', 111: 'ढ़', 112: 'फ़', 113: 'य़', 114: 'ॠ', 115: 'ॡ', 116: 'ॢ', 117: 'ॣ', 118: '0', 119: '1', 120: '2', 121: '3', 122: '4', 123: '5', 124: '6', 125: '7', 126: '8', 127: '9', 128: 'a', 129: 'b', 130: 'c', 131: 'd', 132: 'e', 133: 'f', 134: 'g', 135: 'h', 136: 'i', 137: 'j', 138: 'k', 139: 'l', 140: 'm', 141: 'n', 142: 'o', 143: 'p', 144: 'q', 145: 'r', 146: 's', 147: 't', 148: 'u', 149: 'v', 150: 'w', 151: 'x', 152: 'y', 153: 'z'}

# %%
with open ('characterToClasses.json', 'w') as fp:
    json.dump(classesCharacter, fp)
